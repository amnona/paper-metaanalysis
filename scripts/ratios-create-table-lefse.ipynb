# %%
import calour as ca
import calour_utils as cu
# Out:
# failed to load logging config file

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd
import shutil
import subprocess

# %%
ca.set_log_level('INFO')

# %%
# %matplotlib inline

# %%
pwd
# Out:
# '/Users/amnon/git/paper-metaanalysis/scripts'

# %%
pd.__version__
# Out:
# '1.2.5'

# %%
from os.path import join
save_dir = '../lefse_ratios/'

# %% [markdown]
# # Prepare the ratios table
# ## For each study in the directory, calculate the sick/healthy ratio for each bacteria
# ### Steps:
# #### For each study identify bacteria significantly different between sick/healthy
# Using at most 23 sick and 10 healthy samples per study (for fair comparison between study sizes)
#
# Using FDR=0.25
# #### Join the significant bacteria from all studies
# To a single list
# #### Calculate the log2(sick/healthy) for each bacteria in each study
# On all samples from each study (to get better estimate of the effect size).
#
# Save in a biom table. 1 entry per bacteria per study (log2 ratio sick/healthy)

# %%
def save_for_lefse(exp, field, out_file):
    '''Save a calour experiment for Lefse analysis (adding sample id in first row, field values the 2nd row)
    After calling this function, run:
        lefse_format_input.py OUT_FILE PREPARED_FILE_NAME -c 2 -u 1
    and then:
        lefse_run.py PREPARED_FILE_NAME LEFSE_OUTPUT_FILE -a 1 -l 2 -w 1
    '''
    df = exp.to_pandas(sparse=False).transpose()
    header_field=exp.sample_metadata[field].to_frame().transpose()
    df = header_field.append(df)
    df.to_csv(out_file,sep='\t')

# %%
def norm_diff_lefse(exp, outfile, field='type', val1='HC', val2='disease', alpha=0.25, **kwargs):
    '''identify significant bacteria and effect sizes using lefse
    
    Parameters
    ----------
    
    Returns
    -------
    calour.AmpliconExperiment with significant (level alpha no FDR) features differentiating between val1 and val2 in field
    _calour_stat is negative for val2, positive for val1
    '''
    import subprocess

    exp=exp.filter_samples(field,[val1, val2])
    save_for_lefse(exp, field, outfile+'.table.txt')
    res=subprocess.run(['lefse_format_input.py',outfile+'.table.txt', outfile+'.lefse.prep','-c','2','-u','1'],stderr=subprocess.PIPE, text=True)    
    if res.returncode!=0:
        print('error on lefse_format_input.py for file %s:\n%s' % (outfile, res.stderr))
        return None

    res=subprocess.run(['lefse_run.py',outfile+'.lefse.prep',outfile+'.lefse.txt','-a','1','-l','0','-w','1'], stderr=subprocess.PIPE, text=True)
    if res.returncode!=0:
        print('error on lefse_run.py for file %s:\n%s' % (outfile, res.stderr))
        return None
    
    df=pd.read_csv(outfile+'.lefse.txt',sep='\t',names=['seq','wilcox','group','lda','pval'],index_col=0)
    df['pval']=df.pval.replace('-',2).astype(float)

    # filter keeping only pval <= alpha
    df=df[df['pval']<=alpha]
    
    df['_calour_stat']=df['lda'].copy()
    # fix the direction of the lda to negative for higher in val2
    df.loc[df['group']==val2,'_calour_stat']=-1*df.loc[df['group']==val2,'_calour_stat']
    df['_calour_direction']=df['group'].copy()
    df['_calour_pval']=df['pval'].copy()
    df['_feature_id']=df.index.values

    # create the experiment
    ca.set_log_level('INFO')
    dd=exp.filter_ids(df.index.values)
    dd.feature_metadata=df

    dd=dd.sort_samples(field)
    dd=dd.sort_by_metadata('_calour_stat',axis='f')
    return dd

# %%
def diff_all(fasta_file=None, alpha=0.25, subset_size=None, subset_control=None, random_seed=None):
    '''Iterate over "studies" directory. Each subdir is an experiment with a biom table (all.XXX.biom) and map file (up.map.csv).
    The map file contains the field "type" with the values "HC"/"disease".
    If fasta_file is not None, we keep only bacteria from the experiment present in fasta_file (for second stage diff abundace to reduce FDR cost)
    We then do diff. abundance with thresh. alpha
    Finally we save these disease associated bacteria to a new biom table diff-ALPHA.biom
    
    Parameters
    ----------
    fasta_file:str or None, optional
        if not None, keep only bacteria present in fasta_file
    alpha: float, optional
        the alpha value for the dsFDR (see diff_abundance()  )
    subset_size: int or None, optional
        if not None, keep only subset_size samples from each group (HC/disease)
    subset_control: int or None, optional
        if None,  control subset_size is the same as subset_size.
        if not None, this is the minimal control subset_size
    '''
    x = []
    savedir = join(save_dir,'diff-%s' % alpha)
    if subset_control is None:
        subset_control = subset_size
    if subset_size is not None:
        savedir += '-subset-%d' % subset_size
    print('deleting output dir %s' % savedir)
    try:
        shutil.rmtree(savedir)
    except:
        pass
    if fasta_file is not None:
        savedir += '-filtered'
    try:
        os.mkdir(savedir)
    except:
        pass
    num_processed = 0
    for cname in glob.glob('../studies/*'):
        if os.path.isdir(cname):
            # re-set the random seed for each directory since order of directories may vary between OSs
            if random_seed is not None:
                np.random.seed(random_seed)
            print('**********')
            print(cname)
            x.append(cname)
            tables = glob.glob(os.path.join(cname,'all.*biom'))
            print(tables)
            if len(tables)==0:
                print('dir %s does not contain a biom table' % cname)
                continue
            bt=tables[0]
            data=ca.read_amplicon(os.path.join(bt),os.path.join(cname,'up.map.csv'),normalize=10000,min_reads=1000,sparse=False)
            print('-------------')
            print(data)
            # if enough samples, keep only random subet
            if subset_size is not None:
                tt=data.filter_samples('type','HC')
                ns = len(tt.sample_metadata)
                if ns < subset_control:
                    print('not enough controls (%d). skipping' % ns)
                    continue
                # randomly subsample
                rp = np.random.permutation(ns)
                rp = rp[:subset_size]
                new_ids = [tt.sample_metadata['_sample_id'][x] for x in rp]
                # similar for disease
                tt=data.filter_samples('type','disease')
                ns = len(tt.sample_metadata)
                if ns < subset_size:
                    print('not enough disease (%d). skipping' % ns)
                    continue
                # randomly subsample
                rp = np.random.permutation(ns)
                rp = rp[:subset_size]
                new_ids2 = [tt.sample_metadata['_sample_id'][x] for x in rp]
                # join the ids for the sick and controls
                all_ids = new_ids + new_ids2
                # and finally
                data = data.filter_samples('_sample_id',all_ids)
                print('keeping')
            data=data.filter_sum_abundance(10)
            if fasta_file is not None:
                data=data.filter_by_fasta(fasta_file)
            # dd=norm_diff(data,'type','disease', 'HC',alpha=alpha,random_seed=1234)
            dd=norm_diff_lefse(data,os.path.join(cname,'lefse'),'type','disease', 'HC',alpha=alpha)
            savename = os.path.join(savedir,'diff-%s' % (os.path.basename(cname)))
            dd.save_biom(savename+'.biom',add_metadata=None)
            #dd.save_metadata(savename+'.tsv',axis='f')
            dd.save(savename)
            num_processed += 1
    print('processed %d studies' % num_processed)

# %%
ca.set_log_level('ERROR')

# %%
diff_all(alpha=0.1,subset_size=23, subset_control=10, random_seed=2020)
# Out:
# deleting output dir ../lefse_ratios/diff-0.1-subset-23
# **********
# ../studies/61
# ['../studies/61/all.biom']
# -------------
# AmpliconExperiment with 41 samples, 2715 features
# not enough disease (20). skipping
# **********
# ../studies/59
# ['../studies/59/all.biom']
# -------------
# AmpliconExperiment with 33 samples, 2637 features
# not enough disease (17). skipping
# **********
# ../studies/50
# ['../studies/50/all.biom']
# -------------
# AmpliconExperiment with 58 samples, 959 features
# keeping
# Number of significantly discriminative features: 787 ( 787 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 787
# 2022-01-01 23:56:20 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/57
# ['../studies/57/all.biom']
# 2022-01-01 23:56:21 INFO loaded 85 samples, 4058 features
# 2022-01-01 23:56:21 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:56:21 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 4058 features
# keeping
# 2022-01-01 23:56:21 INFO After filtering, 1005 remain.
# Number of significantly discriminative features: 966 ( 966 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 966
# 2022-01-01 23:56:50 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/32
# ['../studies/32/all.biom']
# 2022-01-01 23:56:50 INFO loaded 43 samples, 1748 features
# 2022-01-01 23:56:50 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:56:50 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 1748 features
# keeping
# 2022-01-01 23:56:50 INFO After filtering, 775 remain.
# Number of significantly discriminative features: 770 ( 770 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 770
# 2022-01-01 23:57:12 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/56
# ['../studies/56/all.biom']
# 2022-01-01 23:57:12 INFO loaded 43 samples, 3045 features
# 2022-01-01 23:57:12 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:57:12 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 3045 features
# not enough disease (21). skipping
# **********
# ../studies/51
# ['../studies/51/all.biom']
# 2022-01-01 23:57:12 INFO loaded 164 samples, 3240 features
# 2022-01-01 23:57:12 WARNING These have metadata but do not have data - dropped (2): {'SRR10429951', 'SRR10430029'}
# 2022-01-01 23:57:12 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:57:12 INFO After filtering, 164 remain.
# -------------
# AmpliconExperiment with 164 samples, 3240 features
# keeping
# 2022-01-01 23:57:12 INFO After filtering, 1027 remain.
# Number of significantly discriminative features: 992 ( 992 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 992
# 2022-01-01 23:57:40 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/58
# ['../studies/58/all.biom']
# 2022-01-01 23:57:40 INFO loaded 45 samples, 3005 features
# 2022-01-01 23:57:40 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:57:40 INFO After filtering, 45 remain.
# -------------
# AmpliconExperiment with 45 samples, 3005 features
# not enough disease (22). skipping
# **********
# ../studies/60
# ['../studies/60/all.biom']
# 2022-01-01 23:57:40 INFO loaded 73 samples, 3771 features
# 2022-01-01 23:57:41 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:57:41 INFO After filtering, 73 remain.
# -------------
# AmpliconExperiment with 73 samples, 3771 features
# keeping
# 2022-01-01 23:57:41 INFO After filtering, 935 remain.
# Number of significantly discriminative features: 900 ( 900 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 900
# 2022-01-01 23:58:07 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/34
# ['../studies/34/all.biom']
# 2022-01-01 23:58:07 INFO loaded 32 samples, 1234 features
# 2022-01-01 23:58:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:58:07 INFO After filtering, 32 remain.
# -------------
# AmpliconExperiment with 32 samples, 1234 features
# not enough disease (18). skipping
# **********
# ../studies/33
# ['../studies/33/all.biom']
# 2022-01-01 23:58:07 INFO loaded 58 samples, 1250 features
# 2022-01-01 23:58:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:58:07 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 1250 features
# not enough disease (19). skipping
# **********
# ../studies/20
# ['../studies/20/all.biom']
# 2022-01-01 23:58:07 INFO loaded 174 samples, 1622 features
# 2022-01-01 23:58:07 WARNING These have metadata but do not have data - dropped (1): {'ERR2837004'}
# 2022-01-01 23:58:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:58:07 INFO After filtering, 151 remain.
# -------------
# AmpliconExperiment with 151 samples, 1622 features
# not enough disease (20). skipping
# **********
# ../studies/18
# ['../studies/18/all.biom']
# 2022-01-01 23:58:07 INFO loaded 84 samples, 1183 features
# 2022-01-01 23:58:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:58:07 INFO After filtering, 84 remain.
# -------------
# AmpliconExperiment with 84 samples, 1183 features
# keeping
# 2022-01-01 23:58:07 INFO After filtering, 536 remain.
# Number of significantly discriminative features: 534 ( 534 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 534
# 2022-01-01 23:58:23 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/27
# ['../studies/27/all.biom']
# 2022-01-01 23:58:23 INFO loaded 251 samples, 1403 features
# 2022-01-01 23:58:23 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:58:23 INFO After filtering, 233 remain.
# -------------
# AmpliconExperiment with 233 samples, 1403 features
# keeping
# 2022-01-01 23:58:23 INFO After filtering, 736 remain.
# Number of significantly discriminative features: 680 ( 680 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 680
# 2022-01-01 23:58:42 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/9
# ['../studies/9/all.biom']
# 2022-01-01 23:58:42 INFO loaded 498 samples, 3722 features
# 2022-01-01 23:58:42 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:58:43 INFO After filtering, 497 remain.
# -------------
# AmpliconExperiment with 497 samples, 3722 features
# keeping
# 2022-01-01 23:58:43 INFO After filtering, 715 remain.
# Number of significantly discriminative features: 687 ( 687 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 687
# 2022-01-01 23:59:03 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/11
# ['../studies/11/all.biom']
# 2022-01-01 23:59:03 INFO loaded 109 samples, 2312 features
# 2022-01-01 23:59:03 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:59:03 INFO After filtering, 109 remain.
# -------------
# AmpliconExperiment with 109 samples, 2312 features
# keeping
# 2022-01-01 23:59:03 INFO After filtering, 864 remain.
# Number of significantly discriminative features: 833 ( 833 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 833
# 2022-01-01 23:59:27 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/7
# ['../studies/7/all.biom']
# 2022-01-01 23:59:27 INFO loaded 441 samples, 4403 features
# 2022-01-01 23:59:27 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:59:27 INFO After filtering, 441 remain.
# -------------
# AmpliconExperiment with 441 samples, 4403 features
# keeping
# 2022-01-01 23:59:27 INFO After filtering, 913 remain.
# Number of significantly discriminative features: 868 ( 868 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 868
# 2022-01-01 23:59:51 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/29
# ['../studies/29/all.biom']
# 2022-01-01 23:59:51 INFO loaded 595 samples, 3470 features
# 2022-01-01 23:59:51 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-01 23:59:51 INFO After filtering, 594 remain.
# -------------
# AmpliconExperiment with 594 samples, 3470 features
# keeping
# 2022-01-01 23:59:51 INFO After filtering, 703 remain.
# Number of significantly discriminative features: 669 ( 669 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 669
# 2022-01-02 00:00:11 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/16
# ['../studies/16/all.biom']
# 2022-01-02 00:00:11 INFO loaded 120 samples, 2116 features
# 2022-01-02 00:00:11 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:00:11 INFO After filtering, 119 remain.
# -------------
# AmpliconExperiment with 119 samples, 2116 features
# keeping
# 2022-01-02 00:00:11 INFO After filtering, 710 remain.
# Number of significantly discriminative features: 681 ( 681 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 681
# 2022-01-02 00:00:30 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/42
# ['../studies/42/all.biom']
# 2022-01-02 00:00:30 INFO loaded 99 samples, 3829 features
# 2022-01-02 00:00:30 WARNING These have metadata but do not have data - dropped (6): {'ERR1417474', 'ERR1841805', 'ERR2696902', 'ERR1073898', 'ERR1545879', 'ERR1315870'}
# 2022-01-02 00:00:30 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:00:30 INFO After filtering, 96 remain.
# -------------
# AmpliconExperiment with 96 samples, 3829 features
# keeping
# 2022-01-02 00:00:30 INFO After filtering, 1259 remain.
# Number of significantly discriminative features: 1206 ( 1206 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1206
# 2022-01-02 00:01:05 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/45
# ['../studies/45/all.biom']
# 2022-01-02 00:01:05 INFO loaded 1095 samples, 14981 features
# 2022-01-02 00:01:05 WARNING These have metadata but do not have data - dropped (66): {'ERR1072642', 'ERR1075171', 'ERR1090995', 'ERR2318028', 'ERR2238647', 'ERR1160500', 'ERR1160652', 'ERR1074155', 'ERR1091145', 'ERR1841817', 'ERR1545996', 'ERR2303979', 'ERR1545915', 'ERR1091156', 'ERR1545957', 'ERR1089803', 'ERR1545883', 'ERR1091321', 'ERR2239656', 'ERR1841758', 'ERR1545722', 'ERR1389937', 'ERR2239699', 'ERR1841492', 'ERR1316257', 'ERR2238631', 'ERR1091606', 'ERR1841716', 'ERR1841512', 'ERR1545921', 'ERR2239754', 'ERR1545981', 'ERR1546017', 'ERR1160588', 'ERR1841761', 'ERR1091364', 'ERR1546023', 'ERR2696527', 'ERR1545906', 'ERR1545967', 'ERR1090798', 'ERR1841815', 'ERR1545847', 'ERR1160532', 'ERR1073096', 'ERR1459053', 'ERR1545998', 'ERR1841814', 'ERR1545935', 'ERR1073742', 'ERR1841810', 'ERR1545994', 'ERR1545752', 'ERR1545831', 'ERR1073328', 'ERR1545894', 'ERR1545778', 'ERR1841804', 'ERR2239633', 'ERR1545905', 'ERR1075099', 'ERR1091590', 'ERR1091654', 'ERR1091564', 'ERR1074008', 'ERR1389884'}
# 2022-01-02 00:01:06 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:01:06 INFO After filtering, 1043 remain.
# -------------
# AmpliconExperiment with 1043 samples, 14981 features
# keeping
# 2022-01-02 00:01:07 INFO After filtering, 1041 remain.
# Number of significantly discriminative features: 978 ( 978 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 978
# 2022-01-02 00:01:33 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/6
# ['../studies/6/all.biom']
# 2022-01-02 00:01:33 INFO loaded 620 samples, 4175 features
# 2022-01-02 00:01:33 WARNING These have metadata but do not have data - dropped (4): {'ERR3520757', 'ERR3520927', 'ERR3520666', 'ERR3519122'}
# 2022-01-02 00:01:33 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:01:33 INFO After filtering, 612 remain.
# -------------
# AmpliconExperiment with 612 samples, 4175 features
# keeping
# 2022-01-02 00:01:34 INFO After filtering, 932 remain.
# Number of significantly discriminative features: 876 ( 876 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 876
# 2022-01-02 00:01:58 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/28
# ['../studies/28/all.biom']
# 2022-01-02 00:01:58 INFO loaded 142 samples, 1306 features
# 2022-01-02 00:01:58 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:01:58 INFO After filtering, 135 remain.
# -------------
# AmpliconExperiment with 135 samples, 1306 features
# keeping
# 2022-01-02 00:01:58 INFO After filtering, 684 remain.
# Number of significantly discriminative features: 642 ( 642 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 642
# 2022-01-02 00:02:20 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/17
# ['../studies/17/all.biom']
# 2022-01-02 00:02:20 INFO loaded 50 samples, 2307 features
# 2022-01-02 00:02:20 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:02:20 INFO After filtering, 50 remain.
# -------------
# AmpliconExperiment with 50 samples, 2307 features
# keeping
# 2022-01-02 00:02:20 INFO After filtering, 1054 remain.
# Number of significantly discriminative features: 1016 ( 1016 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1016
# 2022-01-02 00:03:19 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/1
# ['../studies/1/all.biom']
# 2022-01-02 00:03:19 INFO loaded 38 samples, 1082 features
# 2022-01-02 00:03:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:03:19 INFO After filtering, 38 remain.
# -------------
# AmpliconExperiment with 38 samples, 1082 features
# not enough disease (18). skipping
# **********
# ../studies/10
# ['../studies/10/all.biom']
# 2022-01-02 00:03:19 INFO loaded 174 samples, 3295 features
# 2022-01-02 00:03:19 WARNING These have metadata but do not have data - dropped (2): {'SRR1689253', 'SRR1687461'}
# 2022-01-02 00:03:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:03:19 INFO After filtering, 174 remain.
# -------------
# AmpliconExperiment with 174 samples, 3295 features
# keeping
# 2022-01-02 00:03:19 INFO After filtering, 919 remain.
# Number of significantly discriminative features: 893 ( 893 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 893
# 2022-01-02 00:03:46 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/19
# ['../studies/19/all.biom']
# 2022-01-02 00:03:46 INFO loaded 68 samples, 1401 features
# 2022-01-02 00:03:46 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:03:46 INFO After filtering, 68 remain.
# -------------
# AmpliconExperiment with 68 samples, 1401 features
# keeping
# 2022-01-02 00:03:46 INFO After filtering, 643 remain.
# Number of significantly discriminative features: 637 ( 637 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 637
# 2022-01-02 00:04:06 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/26
# ['../studies/26/all.biom']
# 2022-01-02 00:04:06 INFO loaded 1388 samples, 11834 features
# 2022-01-02 00:04:06 WARNING These have metadata but do not have data - dropped (41): {'DB3.265', 'DB3.096', 'DB2.241', 'DB3.103', 'DB3.212', 'DB3.266', 'DB3.108', 'DB3.071', 'DB3.102', 'DB3.218', 'DB3.228', 'DB3.109', 'DB2.069', 'DB2.242', 'DB3.250', 'DB3.078', 'DB3.239', 'DB2.239', 'DB2.135', 'DB3.223', 'DB3.219', 'DB3.234', 'DB2.240', 'DB3.217', 'DB3.251', 'DB3.106', 'DB3.036', 'DB2.245', 'DB3.269', 'DB3.104', 'DB3.229', 'DB2.076', 'DB3.047', 'DB3.107', 'DB3.110', 'DB3.264', 'DB3.230', 'DB3.231', 'DB3.072', 'DB3.196', 'DB3.101'}
WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:04:07 INFO After filtering, 33 remain.
# -------------
# AmpliconExperiment with 33 samples, 780 features
# not enough disease (22). skipping
# **********
# ../studies/21
# ['../studies/21/all.biom']
# 2022-01-02 00:04:07 INFO loaded 178 samples, 2597 features
# 2022-01-02 00:04:07 WARNING These have metadata but do not have data - dropped (1): {'SRR6147218'}
# 2022-01-02 00:04:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:04:07 INFO After filtering, 178 remain.
# -------------
# AmpliconExperiment with 178 samples, 2597 features
# keeping
# 2022-01-02 00:04:07 INFO After filtering, 751 remain.
# Number of significantly discriminative features: 730 ( 730 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 730
# 2022-01-02 00:04:28 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/44
# ['../studies/44/all.biom']
# 2022-01-02 00:04:28 INFO loaded 875 samples, 11915 features
# 2022-01-02 00:04:28 WARNING These have metadata but do not have data - dropped (64): {'ERR1545702', 'ERR1089814', 'ERR1073330', 'ERR1545838', 'ERR1841525', 'ERR1545803', 'ERR1545774', 'ERR1389624', 'ERR1546010', 'ERR1545978', 'ERR1545990', 'ERR1545962', 'ERR1075286', 'ERR1546016', 'ERR1074005', 'ERR1545802', 'ERR1089679', 'ERR1072778', 'ERR1074955', 'ERR1160680', 'ERR1075272', 'ERR1073883', 'ERR1075071', 'ERR1072794', 'ERR1072781', 'ERR1074092', 'ERR1545911', 'ERR1545781', 'ERR1080384', 'ERR1545936', 'ERR1545804', 'ERR1545939', 'ERR2242158', 'ERR2239717', 'ERR1075185', 'ERR1545747', 'ERR1091354', 'ERR1091155', 'ERR1545833', 'ERR1545907', 'ERR1074007', 'ERR1072979', 'ERR1597274', 'ERR1597126', 'ERR1389819', 'ERR1160673', 'ERR1074779', 'ERR1074978', 'ERR1842199', 'ERR1160475', 'ERR1841813', 'ERR1545963', 'ERR1546057', 'ERR1090161', 'ERR1075896', 'ERR1545986', 'ERR1074050', 'ERR1075069', 'ERR1545877', 'ERR1074974', 'ERR1545780', 'ERR1545891', 'ERR1073198', 'ERR1091147'}
# 2022-01-02 00:04:28 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:04:28 INFO After filtering, 835 remain.
# -------------
# AmpliconExperiment with 835 samples, 11915 features
# keeping
# 2022-01-02 00:04:29 INFO After filtering, 868 remain.
# Number of significantly discriminative features: 835 ( 835 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 835
# 2022-01-02 00:04:54 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/43
# ['../studies/43/all.biom']
# 2022-01-02 00:04:54 INFO loaded 91 samples, 3426 features
# 2022-01-02 00:04:54 WARNING These have metadata but do not have data - dropped (9): {'ERR1545876', 'ERR1841803', 'ERR1545849', 'ERR1545914', 'ERR1841752', 'ERR2239660', 'ERR1075067', 'ERR1545813', 'ERR1073734'}
# 2022-01-02 00:04:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:04:54 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 3426 features
# keeping
# 2022-01-02 00:04:54 INFO After filtering, 875 remain.
# Number of significantly discriminative features: 834 ( 834 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 834
# 2022-01-02 00:05:20 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/36
# ['../studies/36/all.biom']
# 2022-01-02 00:05:20 INFO loaded 16 samples, 1191 features
# 2022-01-02 00:05:20 WARNING These have metadata but do not have data - dropped (1): {'ERR1089974'}
# 2022-01-02 00:05:20 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:05:20 INFO After filtering, 15 remain.
# -------------
# AmpliconExperiment with 15 samples, 1191 features
# not enough controls (9). skipping
# **********
# ../studies/31
# ['../studies/31/all.biom']
# 2022-01-02 00:05:20 INFO loaded 70 samples, 1929 features
# 2022-01-02 00:05:20 WARNING These have metadata but do not have data - dropped (18): {'ERR1331859', 'ERR1331861', 'ERR1331867', 'ERR1331860', 'ERR1331862', 'ERR1331871', 'ERR1331856', 'ERR1331870', 'ERR1331863', 'ERR1331858', 'ERR1331865', 'ERR1331864', 'ERR1331872', 'ERR1331869', 'ERR1331814', 'ERR1331866', 'ERR1331868', 'ERR1331857'}
# 2022-01-02 00:05:20 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:05:20 INFO After filtering, 70 remain.
# -------------
# AmpliconExperiment with 70 samples, 1929 features
# keeping
# 2022-01-02 00:05:20 INFO After filtering, 807 remain.
# Number of significantly discriminative features: 784 ( 784 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 784
# 2022-01-02 00:05:45 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/62
# ['../studies/62/all.biom']
# 2022-01-02 00:05:45 INFO loaded 196 samples, 5813 features
# 2022-01-02 00:05:45 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:05:45 INFO After filtering, 196 remain.
# -------------
# AmpliconExperiment with 196 samples, 5813 features
# keeping
# 2022-01-02 00:05:45 INFO After filtering, 986 remain.
# Number of significantly discriminative features: 951 ( 951 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 951
# 2022-01-02 00:06:14 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/54
# ['../studies/54/all.biom']
# 2022-01-02 00:06:14 INFO loaded 63 samples, 3657 features
# 2022-01-02 00:06:14 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:06:14 INFO After filtering, 63 remain.
# -------------
# AmpliconExperiment with 63 samples, 3657 features
# keeping
# 2022-01-02 00:06:14 INFO After filtering, 1040 remain.
# Number of significantly discriminative features: 1009 ( 1009 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1009
# 2022-01-02 00:06:45 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/53
# ['../studies/53/all.biom']
# 2022-01-02 00:06:45 INFO loaded 115 samples, 4878 features
# 2022-01-02 00:06:45 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:06:45 INFO After filtering, 115 remain.
# -------------
# AmpliconExperiment with 115 samples, 4878 features
# keeping
# 2022-01-02 00:06:45 INFO After filtering, 1050 remain.
# Number of significantly discriminative features: 1006 ( 1006 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1006
# 2022-01-02 00:07:16 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/37
# ['../studies/37/all.biom']
# 2022-01-02 00:07:16 INFO loaded 757 samples, 12055 features
# 2022-01-02 00:07:16 WARNING These have metadata but do not have data - dropped (63): {'ERR1080064', 'ERR1076845', 'ERR1091073', 'ERR1316091', 'ERR1545979', 'ERR1546066', 'ERR1073219', 'ERR1091311', 'ERR1841811', 'ERR1545954', 'ERR1072865', 'ERR1075259', 'ERR1545863', 'ERR1545999', 'ERR1080269', 'ERR1090142', 'ERR1841696', 'ERR1545856', 'ERR1075115', 'ERR1545860', 'ERR2238737', 'ERR2239796', 'ERR1545835', 'ERR1841719', 'ERR2239311', 'ERR1072872', 'ERR1389829', 'ERR1458825', 'ERR2239190', 'ERR1074977', 'ERR2239672', 'ERR1077624', 'ERR1545837', 'ERR1545995', 'ERR1315992', 'ERR1545922', 'ERR1091094', 'ERR1073095', 'ERR1091687', 'ERR2580081', 'ERR2239648', 'ERR1545931', 'ERR1546000', 'ERR1075799', 'ERR1545811', 'ERR1072691', 'ERR1545779', 'ERR1459193', 'ERR1091136', 'ERR1458945', 'ERR1545899', 'ERR1091610', 'ERR1075296', 'ERR1389679', 'ERR1545934', 'ERR1091456', 'ERR2239737', 'ERR1545721', 'ERR1842276', 'ERR1072933', 'ERR1841820', 'ERR1545923', 'ERR1091704'}
# 2022-01-02 00:07:16 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:07:16 INFO After filtering, 727 remain.
# -------------
# AmpliconExperiment with 727 samples, 12055 features
# keeping
# 2022-01-02 00:07:17 INFO After filtering, 1011 remain.
# Number of significantly discriminative features: 950 ( 950 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 950
# 2022-01-02 00:07:43 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/39
# ['../studies/39/all.biom']
# 2022-01-02 00:07:43 INFO loaded 625 samples, 10422 features
# 2022-01-02 00:07:43 WARNING These have metadata but do not have data - dropped (35): {'ERR1074160', 'ERR1545903', 'ERR1075897', 'ERR1842514', 'ERR1073258', 'ERR1545942', 'ERR1389924', 'ERR1545875', 'ERR1841821', 'ERR1074953', 'ERR2239770', 'ERR1545985', 'ERR2239393', 'ERR1080069', 'ERR1854699', 'ERR1842590', 'ERR1089998', 'ERR2239308', 'ERR2318018', 'ERR1545815', 'ERR1841495', 'ERR2238750', 'ERR1545969', 'ERR1074855', 'ERR1076837', 'ERR2239697', 'ERR1077488', 'ERR1073829', 'ERR1841812', 'ERR1389959', 'ERR1072703', 'ERR2238658', 'ERR1072835', 'ERR1545842', 'ERR2239793'}
# 2022-01-02 00:07:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:07:44 INFO After filtering, 587 remain.
# -------------
# AmpliconExperiment with 587 samples, 10422 features
# keeping
# 2022-01-02 00:07:44 INFO After filtering, 997 remain.
# Number of significantly discriminative features: 939 ( 939 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 939
# 2022-01-02 00:08:11 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/52
# ['../studies/52/all.biom']
# 2022-01-02 00:08:11 INFO loaded 30 samples, 2580 features
# 2022-01-02 00:08:11 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:08:11 INFO After filtering, 30 remain.
# -------------
# AmpliconExperiment with 30 samples, 2580 features
# not enough disease (13). skipping
# **********
# ../studies/55
# ['../studies/55/all.biom']
# 2022-01-02 00:08:11 INFO loaded 74 samples, 3939 features
# 2022-01-02 00:08:11 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:08:11 INFO After filtering, 74 remain.
# -------------
# AmpliconExperiment with 74 samples, 3939 features
# keeping
# 2022-01-02 00:08:11 INFO After filtering, 999 remain.
# Number of significantly discriminative features: 963 ( 963 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 963
# 2022-01-02 00:08:39 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/46
# ['../studies/46/all.biom']
# 2022-01-02 00:08:39 INFO loaded 584 samples, 10980 features
# 2022-01-02 00:08:39 WARNING These have metadata but do not have data - dropped (41): {'ERR1841755', 'ERR1074885', 'ERR1545859', 'ERR2239804', 'ERR1841546', 'ERR2239582', 'ERR1545961', 'ERR1073073', 'ERR1545694', 'ERR1545968', 'ERR1073802', 'ERR1074261', 'ERR1546003', 'ERR2238718', 'ERR1545678', 'ERR1459007', 'ERR1073933', 'ERR1545902', 'ERR1545904', 'ERR1074071', 'ERR1077699', 'ERR1546027', 'ERR1545890', 'ERR1080238', 'ERR1075338', 'ERR1546040', 'ERR1545965', 'ERR1545701', 'ERR1841818', 'ERR2242536', 'ERR2239702', 'ERR1854779', 'ERR1075243', 'ERR1545916', 'ERR2304178', 'ERR1389664', 'ERR1089939', 'ERR1089788', 'ERR1073744', 'ERR1545910', 'ERR1075226'}
# 2022-01-02 00:08:39 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:08:39 INFO After filtering, 554 remain.
# -------------
# AmpliconExperiment with 554 samples, 10980 features
# keeping
# 2022-01-02 00:08:39 INFO After filtering, 1160 remain.
# Number of significantly discriminative features: 1094 ( 1094 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1094
# 2022-01-02 00:09:11 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/41
# ['../studies/41/all.biom']
# 2022-01-02 00:09:11 INFO loaded 84 samples, 3557 features
# 2022-01-02 00:09:11 WARNING These have metadata but do not have data - dropped (5): {'ERR1160360', 'ERR2238709', 'ERR1545772', 'ERR2238703', 'ERR1075045'}
# 2022-01-02 00:09:11 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:09:11 INFO After filtering, 80 remain.
# -------------
# AmpliconExperiment with 80 samples, 3557 features
# keeping
# 2022-01-02 00:09:11 INFO After filtering, 1069 remain.
# Number of significantly discriminative features: 1010 ( 1010 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1010
# 2022-01-02 00:09:39 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/48
# ['../studies/48/all.biom']
# 2022-01-02 00:09:39 INFO loaded 293 samples, 6184 features
# 2022-01-02 00:09:39 WARNING These have metadata but do not have data - dropped (21): {'ERR1841718', 'ERR1073280', 'ERR2308577', 'ERR1091689', 'ERR2238646', 'ERR1545869', 'ERR1545775', 'ERR1546022', 'ERR1841798', 'ERR1089880', 'ERR1091390', 'ERR1089851', 'ERR1089874', 'ERR1545878', 'ERR1075875', 'ERR2239290', 'ERR2033565', 'ERR1075817', 'ERR1546021', 'ERR1090826', 'ERR1160560'}
# 2022-01-02 00:09:39 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:09:39 INFO After filtering, 280 remain.
# -------------
# AmpliconExperiment with 280 samples, 6184 features
# keeping
# 2022-01-02 00:09:39 INFO After filtering, 886 remain.
# Number of significantly discriminative features: 848 ( 848 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 848
# 2022-01-02 00:10:03 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/24
# ['../studies/24/all.biom']
# 2022-01-02 00:10:03 INFO loaded 25 samples, 999 features
# 2022-01-02 00:10:03 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:10:03 INFO After filtering, 25 remain.
# -------------
# AmpliconExperiment with 25 samples, 999 features
# not enough disease (15). skipping
# **********
# ../studies/23
# ['../studies/23/all.biom']
# 2022-01-02 00:10:03 INFO loaded 114 samples, 1867 features
# 2022-01-02 00:10:03 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:10:03 INFO After filtering, 114 remain.
# -------------
# AmpliconExperiment with 114 samples, 1867 features
# keeping
# 2022-01-02 00:10:03 INFO After filtering, 584 remain.
# Number of significantly discriminative features: 555 ( 555 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 555
# 2022-01-02 00:10:18 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/4
# ['../studies/4/all.biom']
# 2022-01-02 00:10:18 INFO loaded 83 samples, 1652 features
# 2022-01-02 00:10:18 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:10:18 INFO After filtering, 82 remain.
# -------------
# AmpliconExperiment with 82 samples, 1652 features
# keeping
# 2022-01-02 00:10:18 INFO After filtering, 1074 remain.
# Number of significantly discriminative features: 1021 ( 1021 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1021
# 2022-01-02 00:10:46 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/15
# ['../studies/15/all.biom']
# 2022-01-02 00:10:46 INFO loaded 174 samples, 2103 features
# 2022-01-02 00:10:46 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00
.225', 'DB4.145', 'DB5.225', 'DB2.000', 'DB7.058', 'DB2.155', 'DB4.059', 'DB5.256', 'DB7.212', 'DB10.180', 'DB5.212', 'DB8.171', 'DB9.056', 'DB7.008', 'DB10.155', 'DB7.014', 'DB2.197', 'DB4.024', 'DB7.214', 'DB6.010', 'DB9.274', 'DB8.286', 'DB9.031', 'DB5.156', 'DB4.226', 'DB4.215', 'DB9.289', 'DB2.106', 'DB3.130', 'DB9.177', 'DB6.035', 'DB3.012', 'DB10.120', 'DB2.235', 'DB2.131', 'DB9.074', 'DB9.131', 'DB8.023', 'DB ...
# 2022-01-02 00:11:34 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:11:34 INFO After filtering, 2373 remain.
# -------------
# AmpliconExperiment with 2373 samples, 13732 features
# keeping
# 2022-01-02 00:11:35 INFO After filtering, 745 remain.
# Number of significantly discriminative features: 710 ( 710 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 710
# 2022-01-02 00:11:54 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/49
# ['../studies/49/all.biom']
# 2022-01-02 00:11:54 INFO loaded 273 samples, 8112 features
# 2022-01-02 00:11:54 WARNING These have metadata but do not have data - dropped (28): {'ERR1090164', 'ERR1545777', 'ERR1545713', 'ERR1545980', 'ERR2238662', 'ERR1091143', 'ERR1841753', 'ERR1841517', 'ERR1080264', 'ERR1091017', 'ERR1545898', 'ERR1075006', 'ERR1545737', 'ERR1091581', 'ERR1090029', 'ERR1546004', 'ERR1545736', 'ERR1090991', 'ERR1841808', 'ERR1074598', 'ERR1545971', 'ERR1545766', 'ERR1545712', 'ERR1090999', 'ERR2032154', 'ERR1091007', 'ERR1074963', 'ERR1546037'}
# 2022-01-02 00:11:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:11:54 INFO After filtering, 263 remain.
# -------------
# AmpliconExperiment with 263 samples, 8112 features
# keeping
# 2022-01-02 00:11:54 INFO After filtering, 1096 remain.
# Number of significantly discriminative features: 1044 ( 1044 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1044
# 2022-01-02 00:12:22 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/40
# ['../studies/40/all.biom']
# 2022-01-02 00:12:22 INFO loaded 86 samples, 3917 features
# 2022-01-02 00:12:22 WARNING These have metadata but do not have data - dropped (7): {'ERR1091444', 'ERR1075021', 'ERR1073218', 'ERR1841756', 'ERR2580024', 'ERR1091053', 'ERR1090007'}
# 2022-01-02 00:12:22 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:12:22 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 3917 features
# keeping
# 2022-01-02 00:12:22 INFO After filtering, 1239 remain.
# Number of significantly discriminative features: 1208 ( 1208 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1208
# 2022-01-02 00:12:56 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/47
# ['../studies/47/all.biom']
# 2022-01-02 00:12:56 INFO loaded 257 samples, 7437 features
# 2022-01-02 00:12:56 WARNING These have metadata but do not have data - dropped (17): {'ERR1073703', 'ERR1545948', 'ERR1074882', 'ERR1458779', 'ERR1091044', 'ERR1545836', 'ERR1091085', 'ERR1160308', 'ERR1545953', 'ERR1841629', 'ERR1546002', 'ERR1841809', 'ERR1841802', 'ERR1073252', 'ERR1841777', 'ERR1545812', 'ERR1091158'}
# 2022-01-02 00:12:56 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00
INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/14
# ['../studies/14/all.biom']
# 2022-01-02 00:14:08 INFO loaded 123 samples, 1271 features
# 2022-01-02 00:14:08 WARNING These have metadata but do not have data - dropped (57): {'SRR6307716', 'SRR6307721', 'SRR6804658', 'SRR6307778', 'SRR6307754', 'SRR6307782', 'SRR6804660', 'SRR6307792', 'SRR6307750', 'SRR6307719', 'SRR6307795', 'SRR6804662', 'SRR6307793', 'SRR6307779', 'SRR6307717', 'SRR6307788', 'SRR6804666', 'SRR6307715', 'SRR6804655', 'SRR6307713', 'SRR6307780', 'SRR6804663', 'SRR6307755', 'SRR6804659', 'SRR6307777', 'SRR6804661', 'SRR6307758', 'SRR6307789', 'SRR6307756', 'SRR6307718', 'SRR6804653', 'SRR6307776', 'SRR6307753', 'SRR6307781', 'SRR6307796', 'SRR6307751', 'SRR6804654', 'SRR6307759', 'SRR6804652', 'SRR6804656', 'SRR6307797', 'SRR6307757', 'SRR6307774', 'SRR6804657', 'SRR6307794', 'SRR6804664', 'SRR6307791', 'SRR6804665', 'SRR6307720', 'SRR6307775', 'SRR6307773', 'SRR6307760', 'SRR6307790', 'SRR6307712', 'SRR6307733', 'SRR6307714', 'SRR6307734'}
# 2022-01-02 00:14:08 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:14:08 INFO After filtering, 123 remain.
# -------------
# AmpliconExperiment with 123 samples, 1271 features
# keeping
# 2022-01-02 00:14:08 INFO After filtering, 683 remain.
# Number of significantly discriminative features: 663 ( 663 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 663
# 2022-01-02 00:14:25 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/22
# ['../studies/22/all.biom']
# 2022-01-02 00:14:25 INFO loaded 144 samples, 2687 features
# 2022-01-02 00:14:25 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:14:25 INFO After filtering, 144 remain.
# -------------
# AmpliconExperiment with 144 samples, 2687 features
# keeping
# 2022-01-02 00:14:25 INFO After filtering, 805 remain.
# Number of significantly discriminative features: 790 ( 790 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 790
# 2022-01-02 00:14:46 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/25
# ['../studies/25/all.biom']
# 2022-01-02 00:14:46 INFO loaded 92 samples, 1781 features
# 2022-01-02 00:14:46 WARNING These have metadata but do not have data - dropped (1): {'ERR1776941'}
# 2022-01-02 00:14:46 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:14:46 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 1781 features
# not enough disease (20). skipping
# processed 44 studies

# %% [markdown]
# # load everything and save to a single table and fasta file

# %%
def merge_results(files_dir):
    '''Load the results of the diff_all() and merge to a single table
    save the sequences to "combined-FILES-DIR.fasta"
    returns the Experiment
    '''
    df = None
    all_filenames = glob.glob(join(save_dir, files_dir) + "/*_feature.txt")
    print(all_filenames)
    for j,f in enumerate(all_filenames):
        dt=pd.read_csv((f), sep='\t')
        # print(dt)
        if '_feature_id' not in dt.columns:
            dt['_feature_id']=dt['seq'].copy()
        dt=dt[['_feature_id', '_calour_stat']]
        ccolname='-'.join(os.path.basename(f).split('-')[1:]).split('_feature.txt')[0]
        dt=dt.rename(columns = { '_calour_stat': ccolname})
        if df is None:
            df = dt
        else:
            df=pd.merge(df, dt, how='outer', on = '_feature_id')
#     print('processed %d files' % (j+1))
    df.fillna(value=0, inplace=True)
    oname = join(save_dir, 'combined-%s' % files_dir)
    df.to_csv(oname + '.tsv', sep='\t', index=False, encoding='utf-8-sig')
    df=df.set_index('_feature_id',drop=False)
    exp = ca.Experiment.from_pandas(df.transpose())
    exp.save_fasta(oname+'.fasta')
    return exp

# %%
exp = merge_results('diff-0.25-subset-23')
# Out:
# ['../lefse_ratios/diff-0.25-subset-23/diff-12_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-62_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-50_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-45_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-4_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-29_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-40_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-49_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-39_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-17_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-55_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-14_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-2_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-43_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-7_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-46_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-18_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-53_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-23_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-11_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-54_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-48_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-9_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-16_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-41_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-31_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-28_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-5_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-44_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-21_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-51_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-60_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-10_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-22_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-37_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-47_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-6_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-19_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-42_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-3_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-32_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-15_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-57_feature.txt', '../lefse_ratios/diff-0.25-subset-23/diff-27_feature.txt']

# %% [markdown]
# # redo diff abundance with fasta filtering
# in order to get effect size. so we use alpha=1

# %%
diff_all(fasta_file=join(save_dir,'combined-diff-0.25-subset-23.fasta'),alpha=1,subset_size=None)
# Out:
# deleting output dir ../lefse_ratios/diff-1
# **********
# ../studies/61
# ['../studies/61/all.biom']
# 2022-01-02 00:14:47 INFO loaded 41 samples, 2715 features
# 2022-01-02 00:14:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:14:47 INFO After filtering, 41 remain.
# -------------
# AmpliconExperiment with 41 samples, 2715 features
# 2022-01-02 00:14:47 INFO After filtering, 892 remain.
# Number of significantly discriminative features: 759 ( 759 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 759
# 2022-01-02 00:15:11 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/59
# ['../studies/59/all.biom']
# 2022-01-02 00:15:11 INFO loaded 33 samples, 2637 features
# 2022-01-02 00:15:11 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:15:11 INFO After filtering, 33 remain.
# -------------
# AmpliconExperiment with 33 samples, 2637 features
# 2022-01-02 00:15:11 INFO After filtering, 826 remain.
# Number of significantly discriminative features: 680 ( 680 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 680
# 2022-01-02 00:15:30 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/50
# ['../studies/50/all.biom']
# 2022-01-02 00:15:30 INFO loaded 58 samples, 959 features
# 2022-01-02 00:15:30 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:15:30 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 959 features
# 2022-01-02 00:15:30 INFO After filtering, 930 remain.
# Number of significantly discriminative features: 779 ( 779 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 779
# 2022-01-02 00:15:51 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/57
# ['../studies/57/all.biom']
# 2022-01-02 00:15:51 INFO loaded 85 samples, 4058 features
# 2022-01-02 00:15:51 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:15:51 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 4058 features
# 2022-01-02 00:15:51 INFO After filtering, 1401 remain.
# Number of significantly discriminative features: 1062 ( 1062 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1062
# 2022-01-02 00:16:24 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/32
# ['../studies/32/all.biom']
# 2022-01-02 00:16:24 INFO loaded 43 samples, 1748 features
# 2022-01-02 00:16:24 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:16:24 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 1748 features
# 2022-01-02 00:16:24 INFO After filtering, 860 remain.
# Number of significantly discriminative features: 751 ( 751 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 751
# 2022-01-02 00:16:44 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/56
# ['../studies/56/all.biom']
# 2022-01-02 00:16:44 INFO loaded 43 samples, 3045 features
# 2022-01-02 00:16:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:16:44 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 3045 features
# 2022-01-02 00:16:44 INFO After filtering, 1008 remain.
# Number of significantly discriminative features: 819 ( 819 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 819
# 2022-01-02 00:17:07 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/51
# ['../studies/51/all.biom']
# 2022-01-02 00:17:07 INFO loaded 164 samples, 3240 features
# 2022-01-02 00:17:07 WARNING These have metadata but do not have data - dropped (2): {'SRR10429951', 'SRR10430029'}
# 2022-01-02 00:17:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:17:07 INFO After filtering, 164 remain.
# -------------
# AmpliconExperiment with 164 samples, 3240 features
# 2022-01-02 00:17:07 INFO After filtering, 1983 remain.
# Number of significantly discriminative features: 1278 ( 1278 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1278
# 2022-01-02 00:18:04 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/58
# ['../studies/58/all.biom']
# 2022-01-02 00:18:04 INFO loaded 45 samples, 3005 features
# 2022-01-02 00:18:04 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:18:04 INFO After filtering, 45 remain.
# -------------
# AmpliconExperiment with 45 samples, 3005 features
# 2022-01-02 00:18:04 INFO After filtering, 970 remain.
# Number of significantly discriminative features: 816 ( 816 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 816
# 2022-01-02 00:18:26 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/60
# ['../studies/60/all.biom']
# 2022-01-02 00:18:26 INFO loaded 73 samples, 3771 features
# 2022-01-02 00:18:26 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:18:26 INFO After filtering, 73 remain.
# -------------
# AmpliconExperiment with 73 samples, 3771 features
# 2022-01-02 00:18:26 INFO After filtering, 1212 remain.
# Number of significantly discriminative features: 964 ( 964 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 964
# 2022-01-02 00:18:54 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/34
# ['../studies/34/all.biom']
# 2022-01-02 00:18:54 INFO loaded 32 samples, 1234 features
# 2022-01-02 00:18:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:18:54 INFO After filtering, 32 remain.
# -------------
# AmpliconExperiment with 32 samples, 1234 features
# 2022-01-02 00:18:54 INFO After filtering, 796 remain.
# Number of significantly discriminative features: 507 ( 507 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 507
# 2022-01-02 00:19:08 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/33
# ['../studies/33/all.biom']
# 2022-01-02 00:19:08 INFO loaded 58 samples, 1250 features
# 2022-01-02 00:19:08 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:19:08 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 1250 features
# 2022-01-02 00:19:08 INFO After filtering, 777 remain.
# Number of significantly discriminative features: 625 ( 625 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 625
# 2022-01-02 00:19:25 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/20
# ['../studies/20/all.biom']
# 2022-01-02 00:19:26 INFO loaded 174 samples, 1622 features
# 2022-01-02 00:19:26 WARNING These have metadata but do not have data - dropped (1): {'ERR2837004'}
# 2022-01-02 00:19:26 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:19:26 INFO After filtering, 151 remain.
# -------------
# AmpliconExperiment with 151 samples, 1622 features
# 2022-01-02 00:19:26 INFO After filtering, 1446 remain.
# Number of significantly discriminative features: 929 ( 929 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 929
# 2022-01-02 00:19:55 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/18
# ['../studies/18/all.biom']
# 2022-01-02 00:19:55 INFO loaded 84 samples, 1183 features
# 2022-01-02 00:19:55 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:19:55 INFO After filtering, 84 remain.
# -------------
# AmpliconExperiment with 84 samples, 1183 features
# 2022-01-02 00:19:55 INFO After filtering, 680 remain.
# Number of significantly discriminative features: 626 ( 626 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 626
# 2022-01-02 00:20:13 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/27
# ['../studies/27/all.biom']
# 2022-01-02 00:20:13 INFO loaded 251 samples, 1403 features
# 2022-01-02 00:20:13 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:20:13 INFO After filtering, 233 remain.
# -------------
# AmpliconExperiment with 233 samples, 1403 features
# 2022-01-02 00:20:13 INFO After filtering, 1321 remain.
# Number of significantly discriminative features: 914 ( 914 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 914
# 2022-01-02 00:20:46 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/9
# ['../studies/9/all.biom']
# 2022-01-02 00:20:46 INFO loaded 498 samples, 3722 features
# 2022-01-02 00:20:46 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:20:46 INFO After filtering, 497 remain.
# -------------
# AmpliconExperiment with 497 samples, 3722 features
# 2022-01-02 00:20:47 INFO After filtering, 2632 remain.
# Number of significantly discriminative features: 1438 ( 1438 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1438
# 2022-01-02 00:22:00 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/11
# ['../studies/11/all.biom']
# 2022-01-02 00:22:00 INFO loaded 109 samples, 2312 features
# 2022-01-02 00:22:00 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:22:00 INFO After filtering, 109 remain.
# -------------
# AmpliconExperiment with 109 samples, 2312 features
# 2022-01-02 00:22:00 INFO After filtering, 1266 remain.
# Number of significantly discriminative features: 985 ( 985 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 985
# 2022-01-02 00:22:32 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/7
# ['../studies/7/all.biom']
# 2022-01-02 00:22:32 INFO loaded 441 samples, 4403 features
# 2022-01-02 00:22:32 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:22:32 INFO After filtering, 441 remain.
# -------------
# AmpliconExperiment with 441 samples, 4403 features
# 2022-01-02 00:22:32 INFO After filtering, 2833 remain.
# Number of significantly discriminative features: 1433 ( 1433 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1433
# 2022-01-02 00:23:43 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/29
# ['../studies/29/all.biom']
# 2022-01-02 00:23:43 INFO loaded 595 samples, 3470 features
# 2022-01-02 00:23:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:23:44 INFO After filtering, 594 remain.
# -------------
# AmpliconExperiment with 594 samples, 3470 features
# 2022-01-02 00:23:44 INFO After filtering, 2372 remain.
# Number of significantly discriminative features: 1094 ( 1094 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1094
# 2022-01-02 00:24:47 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/16
# ['../studies/16/all.biom']
# 2022-01-02 00:24:47 INFO loaded 120 samples, 2116 features
# 2022-01-02 00:24:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:24:47 INFO After filtering, 119 remain.
# -------------
# AmpliconExperiment with 119 samples, 2116 features
# 2022-01-02 00:24:47 INFO After filtering, 1103 remain.
# Number of significantly discriminative features: 611 ( 611 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 611
# 2022-01-02 00:25:05 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/42
# ['../studies/42/all.biom']
# 2022-01-02 00:25:05 INFO loaded 99 samples, 3829 features
# 2022-01-02 00:25:05 WARNING These have metadata but do not have data - dropped (6): {'ERR1417474', 'ERR1841805', 'ERR2696902', 'ERR1073898', 'ERR1545879', 'ERR1315870'}
# 2022-01-02 00:25:05 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:25:05 INFO After filtering, 96 remain.
# -------------
# AmpliconExperiment with 96 samples, 3829 features
# 2022-01-02 00:25:05 INFO After filtering, 1738 remain.
# Number of significantly discriminative features: 1100 ( 1100 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1100
# 2022-01-02 00:25:37 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/45
# ['../studies/45/all.biom']
# 2022-01-02 00:25:38 INFO loaded 1095 samples, 14981 features
# 2022-01-02 00:25:38 WARNING These have metadata but do not have data - dropped (66): {'ERR1072642', 'ERR1075171', 'ERR1090995', 'ERR2318028', 'ERR2238647', 'ERR1160500', 'ERR1160652', 'ERR1074155', 'ERR1091145', 'ERR1841817', 'ERR1545996', 'ERR2303979', 'ERR1545915', 'ERR1091156', 'ERR1545957', 'ERR1089803', 'ERR1545883', 'ERR1091321', 'ERR2239656', 'ERR1841758', 'ERR1545722', 'ERR1389937', 'ERR2239699', 'ERR1841492', 'ERR1316257', 'ERR2238631', 'ERR1091606', 'ERR1841716', 'ERR1841512', 'ERR1545921', 'ERR2239754', 'ERR1545981', 'ERR1546017', 'ERR1160588', 'ERR1841761', 'ERR1091364', 'ERR1546023', 'ERR2696527', 'ERR1545906', 'ERR1545967', 'ERR1090798', 'ERR1841815', 'ERR1545847', 'ERR1160532', 'ERR1073096', 'ERR1459053', 'ERR1545998', 'ERR1841814', 'ERR1545935', 'ERR1073742', 'ERR1841810', 'ERR1545994', 'ERR1545752', 'ERR1545831', 'ERR1073328', 'ERR1545894', 'ERR1545778', 'ERR1841804', 'ERR2239633', 'ERR1545905', 'ERR1075099', 'ERR1091590', 'ERR1091654', 'ERR1091564', 'ERR1074008', 'ERR1389884'}
# 2022-01-02 00:25:38 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:25:38 INFO After filtering, 1043 remain.
# -------------
# AmpliconExperiment with 1043 samples, 14981 features
# 2022-01-02 00:25:39 INFO After filtering, 7274 remain.
# Number of significantly discriminative features: 2065 ( 2065 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 2065
# 2022-01-02 00:29:01 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/6
# ['../studies/6/all.biom']
# 2022-01-02 00:29:01 INFO loaded 620 samples, 4175 features
# 2022-01-02 00:29:01 WARNING These have metadata but do not have data - dropped (4): {'ERR3520757', 'ERR3520927', 'ERR3520666', 'ERR3519122'}
# 2022-01-02 00:29:01 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:29:01 INFO After filtering, 612 remain.
# -------------
# AmpliconExperiment with 612 samples, 4175 features
# 2022-01-02 00:29:01 INFO After filtering, 3159 remain.
# Number of significantly discriminative features: 1662 ( 1662 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1662
# 2022-01-02 00:30:45 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/28
# ['../studies/28/all.biom']
# 2022-01-02 00:30:45 INFO loaded 142 samples, 1306 features
# 2022-01-02 00:30:45 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:30:45 INFO After filtering, 135 remain.
# -------------
# AmpliconExperiment with 135 samples, 1306 features
# 2022-01-02 00:30:45 INFO After filtering, 1138 remain.
# Number of significantly discriminative features: 836 ( 836 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 836
# 2022-01-02 00:31:19 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/17
# ['../studies/17/all.biom']
# 2022-01-02 00:31:19 INFO loaded 50 samples, 2307 features
# 2022-01-02 00:31:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:31:19 INFO After filtering, 50 remain.
# -------------
# AmpliconExperiment with 50 samples, 2307 features
# 2022-01-02 00:31:19 INFO After filtering, 1101 remain.
# Number of significantly discriminative features: 857 ( 857 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 857
# 2022-01-02 00:31:47 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/1
# ['../studies/1/all.biom']
# 2022-01-02 00:31:47 INFO loaded 38 samples, 1082 features
# 2022-01-02 00:31:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:31:47 INFO After filtering, 38 remain.
# -------------
# AmpliconExperiment with 38 samples, 1082 features
# 2022-01-02 00:31:47 INFO After filtering, 812 remain.
# Number of significantly discriminative features: 699 ( 699 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 699
# 2022-01-02 00:32:06 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies
 'DB7.135', 'DB5.245', 'DB5.101', 'DB5.080', 'DB4.255', 'DB7.091', 'DB7.130', 'DB7.124', 'DB8.269', 'DB8.175', 'DB4.038', 'DB5.143', 'DB8.182', 'DB7.004', 'DB5.044', 'DB7.268', 'DB8.257', 'DB5.132', 'DB8.070', 'DB8.157', 'DB4.204', 'DB5.144', 'DB8.260', 'DB6.109', 'DB7.065', 'DB4.049', 'DB6.003', 'DB6.103', 'DB6.195', 'DB5.196', 'DB8.225', 'DB6.227', 'DB6.254', 'DB7.044', 'DB5.124', 'DB5.217', 'DB5.290', 'DB6.171', 'DB5.163', 'DB7.238', 'DB6.017', 'DB4.101', 'DB6.177', 'DB4.121', 'DB7.171', 'DB7.168', 'DB7.145', 'DB6.041', 'DB7.069', 'DB4.129', 'DB7.076', 'DB8.128', 'DB7.195', 'DB4.218', 'DB7.193', 'DB8.094', 'DB6.299', 'DB5.098', 'DB5.146', 'DB8.057', 'DB7.244', 'DB4.222', 'DB7.064', 'DB6.237', 'DB7.023', 'DB7.000', 'DB5.202', 'DB8.196', 'DB6.214', 'DB4.120', 'DB5.216', 'DB8.249', 'DB8.077', 'DB8.019', 'DB6.101', 'DB8.041', 'DB8.293', 'DB7.270', 'DB4.145', 'DB8.089', 'DB5.225', 'D ...
# 2022-01-02 00:33:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:33:19 INFO After filtering, 1172 remain.
# -------------
# AmpliconExperiment with 1172 samples, 11834 features
# 2022-01-02 00:33:19 INFO After filtering, 8703 remain.
# Number of significantly discriminative features: 834 ( 834 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 834
# 2022-01-02 00:33:44 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/8
# ['../studies/8/all.biom']
# 2022-01-02 00:33:44 INFO loaded 33 samples, 780 features
# 2022-01-02 00:33:44 WARNING These have metadata but do not have data - dropped (1): {'ERR315306'}
# 2022-01-02 00:33:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:33:44 INFO After filtering, 33 remain.
# -------------
# AmpliconExperiment with 33 samples, 780 features
# 2022-01-02 00:33:44 INFO After filtering, 748 remain.
# Number of significantly discriminative features: 616 ( 616 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 616
# 2022-01-02 00:34:00 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/21
# ['../studies/21/all.biom']
# 2022-01-02 00:34:00 INFO loaded 178 samples, 2597 features
# 2022-01-02 00:34:00 WARNING These have metadata but do not have data - dropped (1): {'SRR6147218'}
# 2022-01-02 00:34:00 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:34:00 INFO After filtering, 178 remain.
# -------------
# AmpliconExperiment with 178 samples, 2597 features
# 2022-01-02 00:34:00 INFO After filtering, 1459 remain.
# Number of significantly discriminative features: 1030 ( 1030 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1030
# 2022-01-02 00:34:35 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/44
# ['../studies/44/all.biom']
# 2022-01-02 00:34:35 INFO loaded 875 samples, 11915 features
# 2022-01-02 00:34:35 WARNING These have metadata but do not have data - dropped (64): {'ERR1545702', 'ERR1089814', 'ERR1073330', 'ERR1545838', 'ERR1841525', 'ERR1545803', 'ERR1545774', 'ERR1389624', 'ERR1546010', 'ERR1545978', 'ERR1545990', 'ERR1545962', 'ERR1075286', 'ERR1546016', 'ERR1074005', 'ERR1545802', 'ERR1089679', 'ERR1072778', 'ERR1074955', 'ERR1160680', 'ERR1075272', 'ERR1073883', 'ERR1075071', 'ERR1072794', 'ERR1072781', 'ERR1074092', 'ERR1545911', 'ERR1545781', 'ERR1080384', 'ERR1545936', 'ERR1545804', 'ERR1545939', 'ERR2242158', 'ERR2239717', 'ERR1075185', 'ERR1545747', 'ERR1091354', 'ERR1091155', 'ERR1545833', 'ERR1545907', 'ERR1074007', 'ERR1072979', 'ERR1597274', 'ERR1597126', 'ERR1389819', 'ERR1160673', 'ERR1074779', 'ERR1074978', 'ERR1842199', 'ERR1160475', 'ERR1841813', 'ERR1545963', 'ERR1546057', 'ERR1090161', 'ERR1075896', 'ERR1545986', 'ERR1074050', 'ERR1075069', 'ERR1545877', 'ERR1074974', 'ERR1545780', 'ERR1545891', 'ERR1073198', 'ERR1091147'}
# 2022-01-02 00:34:35 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:34:35 INFO After filtering, 835 remain.
# -------------
# AmpliconExperiment with 835 samples, 11915 features
# 2022-01-02 00:34:36 INFO After filtering, 4842 remain.
# Number of significantly discriminative features: 1982 ( 1982 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1982
# 2022-01-02 00:37:18 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/43
# ['../studies/43/all.biom']
# 2022-01-02 00:37:18 INFO loaded 91 samples, 3426 features
# 2022-01-02 00:37:18 WARNING These have metadata but do not have data - dropped (9): {'ERR1545876', 'ERR1841803', 'ERR1545849', 'ERR1545914', 'ERR1841752', 'ERR2239660', 'ERR1075067', 'ERR1545813', 'ERR1073734'}
# 2022-01-02 00:37:18 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:37:18 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 3426 features
# 2022-01-02 00:37:18 INFO After filtering, 1502 remain.
# Number of significantly discriminative features: 1077 ( 1077 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1077
# 2022-01-02 00:37:50 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/36
# ['../studies/36/all.biom']
# 2022-01-02 00:37:50 INFO loaded 16 samples, 1191 features
# 2022-01-02 00:37:50 WARNING These have metadata but do not have data - dropped (1): {'ERR1089974'}
# 2022-01-02 00:37:50 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:37:50 INFO After filtering, 15 remain.
# -------------
# AmpliconExperiment with 15 samples, 1191 features
# 2022-01-02 00:37:50 INFO After filtering, 530 remain.
# Number of significantly discriminative features: 459 ( 459 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 459
# 2022-01-02 00:37:58 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/31
# ['../studies/31/all.biom']
# 2022-01-02 00:37:58 INFO loaded 70 samples, 1929 features
# 2022-01-02 00:37:58 WARNING These have metadata but do not have data - dropped (18): {'ERR1331859', 'ERR1331861', 'ERR1331867', 'ERR1331860', 'ERR1331862', 'ERR1331871', 'ERR1331856', 'ERR1331870', 'ERR1331863', 'ERR1331858', 'ERR1331865', 'ERR1331864', 'ERR1331872', 'ERR1331869', 'ERR1331814', 'ERR1331866', 'ERR1331868', 'ERR1331857'}
# 2022-01-02 00:37:58 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:37:58 INFO After filtering, 70 remain.
# -------------
# AmpliconExperiment with 70 samples, 1929 features
# 2022-01-02 00:37:58 INFO After filtering, 988 remain.
# Number of significantly discriminative features: 833 ( 833 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 833
# 2022-01-02 00:38:21 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/62
# ['../studies/62/all.biom']
# 2022-01-02 00:38:21 INFO loaded 196 samples, 5813 features
# 2022-01-02 00:38:21 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:38:21 INFO After filtering, 196 remain.
# -------------
# AmpliconExperiment with 196 samples, 5813 features
# 2022-01-02 00:38:21 INFO After filtering, 2117 remain.
# Number of significantly discriminative features: 1344 ( 1344 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1344
# 2022-01-02 00:39:14 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/54
# ['../studies/54/all.biom']
# 2022-01-02 00:39:14 INFO loaded 63 samples, 3657 features
# 2022-01-02 00:39:14 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:39:14 INFO After filtering, 63 remain.
# -------------
# AmpliconExperiment with 63 samples, 3657 features
# 2022-01-02 00:39:14 INFO After filtering, 1192 remain.
# Number of significantly discriminative features: 957 ( 957 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 957
# 2022-01-02 00:39:41 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/53
# ['../studies/53/all.biom']
# 2022-01-02 00:39:41 INFO loaded 115 samples, 4878 features
# 2022-01-02 00:39:41 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:39:41 INFO After filtering, 115 remain.
# -------------
# AmpliconExperiment with 115 samples, 4878 features
# 2022-01-02 00:39:41 INFO After filtering, 1691 remain.
# Number of significantly discriminative features: 1211 ( 1211 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1211
# 2022-01-02 00:40:19 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/37
# ['../studies/37/all.biom']
# 2022-01-02 00:40:19 INFO loaded 757 samples, 12055 features
# 2022-01-02 00:40:19 WARNING These have metadata but do not have data - dropped (63): {'ERR1080064', 'ERR1076845', 'ERR1091073', 'ERR1316091', 'ERR1545979', 'ERR1546066', 'ERR1073219', 'ERR1091311', 'ERR1841811', 'ERR1545954', 'ERR1072865', 'ERR1075259', 'ERR1545863', 'ERR1545999', 'ERR1080269', 'ERR1090142', 'ERR1841696', 'ERR1545856', 'ERR1075115', 'ERR1545860', 'ERR2238737', 'ERR2239796', 'ERR1545835', 'ERR1841719', 'ERR2239311', 'ERR1072872', 'ERR1389829', 'ERR1458825', 'ERR2239190', 'ERR1074977', 'ERR2239672', 'ERR1077624', 'ERR1545837', 'ERR1545995', 'ERR1315992', 'ERR1545922', 'ERR1091094', 'ERR1073095', 'ERR1091687', 'ERR2580081', 'ERR2239648', 'ERR1545931', 'ERR1546000', 'ERR1075799', 'ERR1545811', 'ERR1072691', 'ERR1545779', 'ERR1459193', 'ERR1091136', 'ERR1458945', 'ERR1545899', 'ERR1091610', 'ERR1075296', 'ERR1389679', 'ERR1545934', 'ERR1091456', 'ERR2239737', 'ERR1545721', 'ERR1842276', 'ERR1072933', 'ERR1841820', 'ERR1545923', 'ERR1091704'}
# 2022-01-02 00:40:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:40:19 INFO After filtering, 727 remain.
# -------------
# AmpliconExperiment with 727 samples, 12055 features
# 2022-01-02 00:40:20 INFO After filtering, 5226 remain.
# Number of significantly discriminative features: 1979 ( 1979 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1979
# 2022-01-02 00:42:48 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/39
# ['../studies/39/all.biom']
# 2022-01-02 00:42:48 INFO loaded 625 samples, 10422 features
# 2022-01-02 00:42:48 WARNING These have metadata but do not have data - dropped (35): {'ERR1074160', 'ERR1545903', 'ERR1075897', 'ERR1842514', 'ERR1073258', 'ERR1545942', 'ERR1389924', 'ERR1545875', 'ERR1841821', 'ERR1074953', 'ERR2239770', 'ERR1545985', 'ERR2239393', 'ERR1080069', 'ERR1854699', 'ERR1842590', 'ERR1089998', 'ERR2239308', 'ERR2318018', 'ERR1545815', 'ERR1841495', 'ERR2238750', 'ERR1545969', 'ERR1074855', 'ERR1076837', 'ERR2239697', 'ERR1077488', 'ERR1073829', 'ERR1841812', 'ERR1389959', 'ERR1072703', 'ERR2238658', 'ERR1072835', 'ERR1545842', 'ERR2239793'}
# 2022-01-02 00:42:48 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:42:48 INFO After filtering, 587 remain.
# -------------
# AmpliconExperiment with 587 samples, 10422 features
# 2022-01-02 00:42:48 INFO After filtering, 4506 remain.
# Number of significantly discriminative features: 1925 ( 1925 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1925
# 2022-01-02 00:44:57 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/52
# ['../studies/52/all.biom']
# 2022-01-02 00:44:57 INFO loaded 30 samples, 2580 features
# 2022-01-02 00:44:57 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:44:57 INFO After filtering, 30 remain.
# -------------
# AmpliconExperiment with 30 samples, 2580 features
# 2022-01-02 00:44:57 INFO After filtering, 820 remain.
# Number of significantly discriminative features: 694 ( 694 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 694
# 2022-01-02 00:45:16 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/55
# ['../studies/55/all.biom']
# 2022-01-02 00:45:16 INFO loaded 74 samples, 3939 features
# 2022-01-02 00:45:16 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:45:16 INFO After filtering, 74 remain.
# -------------
# AmpliconExperiment with 74 samples, 3939 features
# 2022-01-02 00:45:16 INFO After filtering, 1268 remain.
# Number of significantly discriminative features: 985 ( 985 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 985
# 2022-01-02 00:45:45 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/46
# ['../studies/46/all.biom']
# 2022-01-02 00:45:45 INFO loaded 584 samples, 10980 features
# 2022-01-02 00:45:45 WARNING These have metadata but do not have data - dropped (41): {'ERR1841755', 'ERR1074885', 'ERR1545859', 'ERR2239804', 'ERR1841546', 'ERR2239582', 'ERR1545961', 'ERR1073073', 'ERR1545694', 'ERR1545968', 'ERR1073802', 'ERR1074261', 'ERR1546003', 'ERR2238718', 'ERR1545678', 'ERR1459007', 'ERR1073933', 'ERR1545902', 'ERR1545904', 'ERR1074071', 'ERR1077699', 'ERR1546027', 'ERR1545890', 'ERR1080238', 'ERR1075338', 'ERR1546040', 'ERR1545965', 'ERR1545701', 'ERR1841818', 'ERR2242536', 'ERR2239702', 'ERR1854779', 'ERR1075243', 'ERR1545916', 'ERR2304178', 'ERR1389664', 'ERR1089939', 'ERR1089788', 'ERR1073744', 'ERR1545910', 'ERR1075226'}
# 2022-01-02 00:45:46 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:45:46 INFO After filtering, 554 remain.
# -------------
# AmpliconExperiment with 554 samples, 10980 features
# 2022-01-02 00:45:46 INFO After filtering, 4761 remain.
# Number of significantly discriminative features: 1936 ( 1936 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1936
# 2022-01-02 00:47:50 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/41
# ['../studies/41/all.biom']
# 2022-01-02 00:47:51 INFO loaded 84 samples, 3557 features
# 2022-01-02 00:47:51 WARNING These have metadata but do not have data - dropped (5): {'ERR1160360', 'ERR2238709', 'ERR1545772', 'ERR2238703', 'ERR1075045'}
# 2022-01-02 00:47:51 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:47:51 INFO After filtering, 80 remain.
# -------------
# AmpliconExperiment with 80 samples, 3557 features
# 2022-01-02 00:47:51 INFO After filtering, 1434 remain.
# Number of significantly discriminative features: 1067 ( 1067 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1067
# 2022-01-02 00:48:21 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/48
# ['../studies/48/all.biom']
# 2022-01-02 00:48:21 INFO loaded 293 samples, 6184 features
# 2022-01-02 00:48:21 WARNING These have metadata but do not have data - dropped (21): {'ERR1841718', 'ERR1073280', 'ERR2308577', 'ERR1091689', 'ERR2238646', 'ERR1545869', 'ERR1545775', 'ERR1546022', 'ERR1841798', 'ERR1089880', 'ERR1091390', 'ERR1089851', 'ERR1089874', 'ERR1545878', 'ERR1075875', 'ERR2239290', 'ERR2033565', 'ERR1075817', 'ERR1546021', 'ERR1090826', 'ERR1160560'}
# 2022-01-02 00:48:21 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:48:21 INFO After filtering, 280 remain.
# -------------
# AmpliconExperiment with 280 samples, 6184 features
# 2022-01-02 00:48:21 INFO After filtering, 2593 remain.
# Number of significantly discriminative features: 1498 ( 1498 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1498
# 2022-01-02 00:49:23 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/24
# ['../studies/24/all.biom']
# 2022-01-02 00:49:23 INFO loaded 25 samples, 999 features
# 2022-01-02 00:49:23 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:49:23 INFO After filtering, 25 remain.
# -------------
# AmpliconExperiment with 25 samples, 999 features
# 2022-01-02 00:49:23 INFO After filtering, 482 remain.
# Number of significantly discriminative features: 429 ( 429 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 429
# 2022-01-02 00:49:32 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/23
# ['../studies/23/all.biom']
# 2022-01-02 00:49:32 INFO loaded 114 samples, 1867 features
# 2022-01-02 00:49:32 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:49:32 INFO After filtering, 114 remain.
# -------------
# AmpliconExperiment with 114 samples, 1867 features
# 2022-01-02 00:49:32 INFO After filtering, 966 remain.
# Number of significantly discriminative features: 687 ( 687 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 687
# 2022-01-02 00:49:52 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/4
# ['../studies/4/all.biom']
# 2022-01-02 00:49:52 INFO loaded 83 samples, 1652 features
# 2022-01-02 00:49:52 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:49:52 INFO After filtering, 82 remain.
# -------------
# AmpliconExperiment with 82 samples, 1652 features
# 2022-01-02 00:49:52 INFO After filtering, 1408 remain.
# Number of significantly discriminative features: 1059 ( 1059 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1059
# 2022-01-02 00:50:23 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/15
# ['../studies/15/all.biom']
# 2022-01-02 00:50:23 INFO loaded 174 samples, 2103 features
# 2022-01-02 00:50:23 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:50:23 INFO After filtering, 162 remain.
# -------------
# AmpliconExperiment with 162 samples, 2103 features
# 2022-01-02 00:50:23 INFO After filtering, 1552 remain.
# Number of significantly discriminative features: 1064 ( 1064 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1064
# 2022-01-02 00:50:59 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/3
# ['../studies/3/all.biom']
# 2022-01-02 00:50:59 INFO loaded 337 samples, 3021 features
# 2022-01-02 00:50:59 WARNING These have metadata but do not have data - dropped (11): {'ERR1513809', 'ERR1513893', 'ERR1513668', 'ERR1513823', 'ERR1513792', 'ERR1513697', 'ERR1513897', 'ERR1513848', 'ERR1513852', 'ERR1513791', 'ERR1513720'}
# 2022-01-02 00:51:00 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:51:00 INFO After filtering, 334 remain.
# -------------
# AmpliconExperiment with 334 samples, 3021 features
# 2022-01-02 00:51:00 INFO After filtering, 2885 remain.
# Number of significantly discriminative features: 1600 ( 1600 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1600
# 2022-01-02 00:52:13 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies
INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/49
# ['../studies/49/all.biom']
# 2022-01-02 00:53:08 INFO loaded 273 samples, 8112 features
# 2022-01-02 00:53:08 WARNING These have metadata but do not have data - dropped (28): {'ERR1090164', 'ERR1545777', 'ERR1545713', 'ERR1545980', 'ERR2238662', 'ERR1091143', 'ERR1841753', 'ERR1841517', 'ERR1080264', 'ERR1091017', 'ERR1545898', 'ERR1075006', 'ERR1545737', 'ERR1091581', 'ERR1090029', 'ERR1546004', 'ERR1545736', 'ERR1090991', 'ERR1841808', 'ERR1074598', 'ERR1545971', 'ERR1545766', 'ERR1545712', 'ERR1090999', 'ERR2032154', 'ERR1091007', 'ERR1074963', 'ERR1546037'}
# 2022-01-02 00:53:08 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:53:08 INFO After filtering, 263 remain.
# -------------
# AmpliconExperiment with 263 samples, 8112 features
# 2022-01-02 00:53:08 INFO After filtering, 3592 remain.
# Number of significantly discriminative features: 1648 ( 1648 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1648
# 2022-01-02 00:54:19 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/40
# ['../studies/40/all.biom']
# 2022-01-02 00:54:19 INFO loaded 86 samples, 3917 features
# 2022-01-02 00:54:19 WARNING These have metadata but do not have data - dropped (7): {'ERR1091444', 'ERR1075021', 'ERR1073218', 'ERR1841756', 'ERR2580024', 'ERR1091053', 'ERR1090007'}
# 2022-01-02 00:54:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:54:19 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 3917 features
# 2022-01-02 00:54:19 INFO After filtering, 1670 remain.
# Number of significantly discriminative features: 1001 ( 1001 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1001
# 2022-01-02 00:54:48 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/47
# ['../studies/47/all.biom']
# 2022-01-02 00:54:48 INFO loaded 257 samples, 7437 features
# 2022-01-02 00:54:48 WARNING These have metadata but do not have data - dropped (17): {'ERR1073703', 'ERR1545948', 'ERR1074882', 'ERR1458779', 'ERR1091044', 'ERR1545836', 'ERR1091085', 'ERR1160308', 'ERR1545953', 'ERR1841629', 'ERR1546002', 'ERR1841809', 'ERR1841802', 'ERR1073252', 'ERR1841777', 'ERR1545812', 'ERR1091158'}
# 2022-01-02 00:54:48 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:54:48 INFO After filtering, 247 remain.
# -------------
# AmpliconExperiment with 247 samples, 7437 features
# 2022-01-02 00:54:48 INFO After filtering, 2898 remain.
# Number of significantly discriminative features: 1557 ( 1557 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1557
# 2022-01-02 00:55:51 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/2
# ['../studies/2/all.biom']
# 2022-01-02 00:55:51 INFO loaded 179 samples, 2528 features
# 2022-01-02 00:55:51 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:55:51 INFO After filtering, 179 remain.
# -------------
# AmpliconExperiment with 179 samples, 2528 features
# 2022-01-02 00:55:51 INFO After filtering, 1984 remain.
# Number of significantly discriminative features: 1310 ( 1310 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1310
# 2022-01-02 00:56:38 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/13
# ['../studies/13/all.biom']
# 2022-01-02 00:56:38 INFO loaded 31 samples, 925 features
# 2022-01-02 00:56:38 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:56:38 INFO After filtering, 31 remain.
# -------------
# AmpliconExperiment with 31 samples, 925 features
# 2022-01-02 00:56:38 INFO After filtering, 649 remain.
# Number of significantly discriminative features: 573 ( 573 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 573
# 2022-01-02 00:56:54 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies
WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:58:00 INFO After filtering, 123 remain.
# -------------
# AmpliconExperiment with 123 samples, 1271 features
# 2022-01-02 00:58:00 INFO After filtering, 1055 remain.
# Number of significantly discriminative features: 790 ( 790 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 790
# 2022-01-02 00:58:24 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/22
# ['../studies/22/all.biom']
# 2022-01-02 00:58:24 INFO loaded 144 samples, 2687 features
# 2022-01-02 00:58:24 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:58:24 INFO After filtering, 144 remain.
# -------------
# AmpliconExperiment with 144 samples, 2687 features
# 2022-01-02 00:58:24 INFO After filtering, 1469 remain.
# Number of significantly discriminative features: 1031 ( 1031 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 1031
# 2022-01-02 00:58:57 INFO Metadata field taxonomy not found. Saving biom table without metadata
# **********
# ../studies/25
# ['../studies/25/all.biom']
# 2022-01-02 00:58:57 INFO loaded 92 samples, 1781 features
# 2022-01-02 00:58:57 WARNING These have metadata but do not have data - dropped (1): {'ERR1776941'}
# 2022-01-02 00:58:57 WARNING Do you forget to normalize your data? It is required before running this function
# 2022-01-02 00:58:57 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 1781 features
# 2022-01-02 00:58:57 INFO After filtering, 995 remain.
# Number of significantly discriminative features: 748 ( 748 ) before internal wilcoxon
# Number of discriminative features with abs LDA score > 0.0 : 748
# 2022-01-02 00:59:19 INFO Metadata field taxonomy not found. Saving biom table without metadata
# processed 59 studies

# %%
exp = merge_results('diff-1-filtered')
# Out:
# ['../lefse_ratios/diff-1-filtered/diff-12_feature.txt', '../lefse_ratios/diff-1-filtered/diff-62_feature.txt', '../lefse_ratios/diff-1-filtered/diff-50_feature.txt', '../lefse_ratios/diff-1-filtered/diff-20_feature.txt', '../lefse_ratios/diff-1-filtered/diff-45_feature.txt', '../lefse_ratios/diff-1-filtered/diff-4_feature.txt', '../lefse_ratios/diff-1-filtered/diff-29_feature.txt', '../lefse_ratios/diff-1-filtered/diff-59_feature.txt', '../lefse_ratios/diff-1-filtered/diff-40_feature.txt', '../lefse_ratios/diff-1-filtered/diff-1_feature.txt', '../lefse_ratios/diff-1-filtered/diff-8_feature.txt', '../lefse_ratios/diff-1-filtered/diff-49_feature.txt', '../lefse_ratios/diff-1-filtered/diff-39_feature.txt', '../lefse_ratios/diff-1-filtered/diff-17_feature.txt', '../lefse_ratios/diff-1-filtered/diff-25_feature.txt', '../lefse_ratios/diff-1-filtered/diff-55_feature.txt', '../lefse_ratios/diff-1-filtered/diff-26_feature.txt', '../lefse_ratios/diff-1-filtered/diff-56_feature.txt', '../lefse_ratios/diff-1-filtered/diff-14_feature.txt', '../lefse_ratios/diff-1-filtered/diff-33_feature.txt', '../lefse_ratios/diff-1-filtered/diff-2_feature.txt', '../lefse_ratios/diff-1-filtered/diff-43_feature.txt', '../lefse_ratios/diff-1-filtered/diff-7_feature.txt', '../lefse_ratios/diff-1-filtered/diff-46_feature.txt', '../lefse_ratios/diff-1-filtered/diff-36_feature.txt', '../lefse_ratios/diff-1-filtered/diff-18_feature.txt', '../lefse_ratios/diff-1-filtered/diff-53_feature.txt', '../lefse_ratios/diff-1-filtered/diff-23_feature.txt', '../lefse_ratios/diff-1-filtered/diff-11_feature.txt', '../lefse_ratios/diff-1-filtered/diff-61_feature.txt', '../lefse_ratios/diff-1-filtered/diff-54_feature.txt', '../lefse_ratios/diff-1-filtered/diff-24_feature.txt', '../lefse_ratios/diff-1-filtered/diff-48_feature.txt', '../lefse_ratios/diff-1-filtered/diff-9_feature.txt', '../lefse_ratios/diff-1-filtered/diff-16_feature.txt', '../lefse_ratios/diff-1-filtered/diff-41_feature.txt', '../lefse_ratios/diff-1-filtered/diff-31_feature.txt', '../lefse_ratios/diff-1-filtered/diff-58_feature.txt', '../lefse_ratios/diff-1-filtered/diff-28_feature.txt', '../lefse_ratios/diff-1-filtered/diff-34_feature.txt', '../lefse_ratios/diff-1-filtered/diff-5_feature.txt', '../lefse_ratios/diff-1-filtered/diff-44_feature.txt', '../lefse_ratios/diff-1-filtered/diff-21_feature.txt', '../lefse_ratios/diff-1-filtered/diff-51_feature.txt', '../lefse_ratios/diff-1-filtered/diff-13_feature.txt', '../lefse_ratios/diff-1-filtered/diff-60_feature.txt', '../lefse_ratios/diff-1-filtered/diff-10_feature.txt', '../lefse_ratios/diff-1-filtered/diff-22_feature.txt', '../lefse_ratios/diff-1-filtered/diff-52_feature.txt', '../lefse_ratios/diff-1-filtered/diff-37_feature.txt', '../lefse_ratios/diff-1-filtered/diff-47_feature.txt', '../lefse_ratios/diff-1-filtered/diff-6_feature.txt', '../lefse_ratios/diff-1-filtered/diff-19_feature.txt', '../lefse_ratios/diff-1-filtered/diff-42_feature.txt', '../lefse_ratios/diff-1-filtered/diff-3_feature.txt', '../lefse_ratios/diff-1-filtered/diff-32_feature.txt', '../lefse_ratios/diff-1-filtered/diff-15_feature.txt', '../lefse_ratios/diff-1-filtered/diff-57_feature.txt', '../lefse_ratios/diff-1-filtered/diff-27_feature.txt']

# %%
def prepare_exp(f, o):
    '''Prepare the merged experiment for analysis and save it
    
    Parameters
    ----------
    f: str
        name of the tsv file output from merge_results() (XXX.tsv)
    o: str
        name of the output o.biom o.map.tsv
    
    Returns
    -------
    ca.Experiment
    '''
    data=pd.read_csv(join(save_dir,f),sep='\t',index_col='_feature_id')
    dat=data.to_numpy(dtype=float)
    newexp=ca.Experiment(dat.T,sample_metadata=pd.DataFrame(data.columns,index=data.columns),feature_metadata=pd.DataFrame(data.index, index=data.index))
    o = join(save_dir, o)
    newexp.save(o)
#    newexp.save_biom(o+'.biom',add_metadata=None)
#    newexp.save_metadata(o+'.map.tsv')
    xx=ca.read_amplicon(o+'.biom',o+'_sample.txt',normalize=None, min_reads=None)
    return xx

# %% [markdown]
# # Save the ratios table to 'ratios/ratios.biom'
# ## sample metadata in ratios_sample.txt

# %%
xx=prepare_exp('combined-diff-1-filtered.tsv','ratios')
# Out:
# 2022-01-02 00:59:21 INFO Metadata field taxonomy not found. Saving biom table without metadata
# 2022-01-02 00:59:21 INFO loaded 59 samples, 2511 features

# %%
xx
# Out:
# AmpliconExperiment with 59 samples, 2511 features

# %%
xx.sparse=False

# %% [markdown]
# # Create effect size table for all features
# Used to test the lefse effect direction (and mean) for all features identified as significant by NRMD

# %%
def effect_all():
    '''Create a single biom table for all effect size in all samples
    used for comparison to NRMD metric
    
    Returns
    -------
    pandas.dataframe with column for each study, row for each ASV, value is the LEFSE stat (positive is higher in HC)
    '''
    res=pd.DataFrame(columns=['Seq'])
    res=res.set_index('Seq')
    x = []
    savedir = join(save_dir,'effect_all')
    num_processed = 0
    for cname in glob.glob('../studies/*'):
        if os.path.isdir(cname):
            print('**********')
            print(cname)
            ccname = cname.split('/')[-1]
            x.append(cname)
            tables = glob.glob(os.path.join(cname,'lefse.lefse.txt'))
            print(tables)
            if len(tables)==0:
                print('dir %s does not contain a lefse output file' % cname)
                continue
            bt=tables[0]
            df=pd.read_csv(bt,sep='\t',names=['seq','wilcox','group','lda','pval'],index_col=0)
            val2='disease'
            df['_calour_stat']=df['lda'].copy()
            # fix the direction of the lda to negative for higher in val2
            df.loc[df['group']==val2,'lda']=-1*df.loc[df['group']==val2,'lda']
            df=df.loc[:,'lda']
            res=res.merge(df,left_index=True,right_index=True,how='outer')
            res.rename(columns={'lda':ccname}, inplace=True)
            print(len(res))
    return res

# %%
df=effect_all()
# Out:
# **********
# ../studies/61
# ['../studies/61/lefse.lefse.txt']
# 766
# **********
# ../studies/59
# ['../studies/59/lefse.lefse.txt']
# 894
# **********
# ../studies/50
# ['../studies/50/lefse.lefse.txt']
# 1111
# **********
# ../studies/57
# ['../studies/57/lefse.lefse.txt']
# 1322
# **********
# ../studies/32
# ['../studies/32/lefse.lefse.txt']
# 1462
# **********
# ../studies/56
# ['../studies/56/lefse.lefse.txt']
# 1509
# **********
# ../studies/51
# ['../studies/51/lefse.lefse.txt']
# 1711
# **********
# ../studies/58
# ['../studies/58/lefse.lefse.txt']
# 1730
# **********
# ../studies/60
# ['../studies/60/lefse.lefse.txt']
# 1771
# **********
# ../studies/34
# ['../studies/34/lefse.lefse.txt']
# 1854
# **********
# ../studies/33
# ['../studies/33/lefse.lefse.txt']
# 1881
# **********
# ../studies/20
# ['../studies/20/lefse.lefse.txt']
# 1924
# **********
# ../studies/18
# ['../studies/18/lefse.lefse.txt']
# 2002
# **********
# ../studies/27
# ['../studies/27/lefse.lefse.txt']
# 2087
# **********
# ../studies/9
# ['../studies/9/lefse.lefse.txt']
# 2185
# **********
# ../studies/11
# ['../studies/11/lefse.lefse.txt']
# 2199
# **********
# ../studies/7
# ['../studies/7/lefse.lefse.txt']
# 2233
# **********
# ../studies/29
# ['../studies/29/lefse.lefse.txt']
# 2275
# **********
# ../studies/16
# ['../studies/16/lefse.lefse.txt']
# 2328
# **********
# ../studies/42
# ['../studies/42/lefse.lefse.txt']
# 2360
# **********
# ../studies/45
# ['../studies/45/lefse.lefse.txt']
# 2423
# **********
# ../studies/6
# ['../studies/6/lefse.lefse.txt']
# 2432
# **********
# ../studies/28
# ['../studies/28/lefse.lefse.txt']
# 2434
# **********
# ../studies/17
# ['../studies/17/lefse.lefse.txt']
# 2440
# **********
# ../studies/1
# ['../studies/1/lefse.lefse.txt']
# 2440
# **********
# ../studies/10
# ['../studies/10/lefse.lefse.txt']
# 2446
# **********
# ../studies/19
# ['../studies/19/lefse.lefse.txt']
# 2455
# **********
# ../studies/26
# ['../studies/26/lefse.lefse.txt']
# 2463
# **********
# ../studies/8
# ['../studies/8/lefse.lefse.txt']
# 2463
# **********
# ../studies/21
# ['../studies/21/lefse.lefse.txt']
# 2464
# **********
# ../studies/44
# ['../studies/44/lefse.lefse.txt']
# 2473
# **********
# ../studies/43
# ['../studies/43/lefse.lefse.txt']
# 2475
# **********
# ../studies/36
# ['../studies/36/lefse.lefse.txt']
# 2475
# **********
# ../studies/31
# ['../studies/31/lefse.lefse.txt']
# 2480
# **********
# ../studies/62
# ['../studies/62/lefse.lefse.txt']
# 2480
# **********
# ../studies/54
# ['../studies/54/lefse.lefse.txt']
# 2480
# **********
# ../studies/53
# ['../studies/53/lefse.lefse.txt']
# 2482
# **********
# ../studies/37
# ['../studies/37/lefse.lefse.txt']
# 2484
# **********
# ../studies/39
# ['../studies/39/lefse.lefse.txt']
# 2485
# **********
# ../studies/52
# ['../studies/52/lefse.lefse.txt']
# 2485
# **********
# ../studies/55
# ['../studies/55/lefse.lefse.txt']
# 2488
# **********
# ../studies/46
# ['../studies/46/lefse.lefse.txt']
# 2492
# **********
# ../studies/41
# ['../studies/41/lefse.lefse.txt']
# 2493
# **********
# ../studies/48
# ['../studies/48/lefse.lefse.txt']
# 2494
# **********
# ../studies/24
# ['../studies/24/lefse.lefse.txt']
# 2494
# **********
# ../studies/23
# ['../studies/23/lefse.lefse.txt']
# 2496
# **********
# ../studies/4
# ['../studies/4/lefse.lefse.txt']
# 2498
# **********
# ../studies/15
# ['../studies/15/lefse.lefse.txt']
# 2503
# **********
# ../studies/3
# ['../studies/3/lefse.lefse.txt']
# 2503
# **********
# ../studies/12
# ['../studies/12/lefse.lefse.txt']
# 2505
# **********
# ../studies/49
# ['../studies/49/lefse.lefse.txt']
# 2506
# **********
# ../studies/40
# ['../studies/40/lefse.lefse.txt']
# 2506
# **********
# ../studies/47
# ['../studies/47/lefse.lefse.txt']
# 2506
# **********
# ../studies/2
# ['../studies/2/lefse.lefse.txt']
# 2506
# **********
# ../studies/13
# ['../studies/13/lefse.lefse.txt']
# 2506
# **********
# ../studies/5
# ['../studies/5/lefse.lefse.txt']
# 2507
# **********
# ../studies/14
# ['../studies/14/lefse.lefse.txt']
# 2510
# **********
# ../studies/22
# ['../studies/22/lefse.lefse.txt']
# 2511
# **********
# ../studies/25
# ['../studies/25/lefse.lefse.txt']
# 2511

# %%
df.to_csv('../lefse_ratios/all_lefse_ratios.txt',sep='\t')
