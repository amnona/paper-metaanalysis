# %%
import calour as ca
import calour_utils as cu
# Out:
# failed to load logging config file

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd
import shutil
import matplotlib.colors
import skbio as skbio
# Out:
# /Users/amnon/miniconda3/envs/calour/lib/python3.7/site-packages/skbio/util/_testing.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as pdt

# %%
ca.set_log_level('INFO')

# %%
# %matplotlib notebook

# %%
pwd
# Out:
# '/Users/amnon/Projects/sheba/metaanalysis/scripts'

# %% [markdown]
# # Prepare the data

# %%
def join_all_exps(subset_size=23, subset_control=23, keep_less=True,normalize=False, random_seed=None):
    '''load all experiemnts
    to a single dataset aftert subsampling

    Parameters
    ----------
    subset_size: int or None, optional
        if not None, randomly select subset_size samples for case and control groups each
    subset_control: int or None, optional
        if subset_size is not None, randomly select subset_control control samples. If None, use value of subset_size
    keep_less: bool
        True to also keep studies with < subset_size samples.
        False to throw away studies with < subset_size samples.
    normalize: bool, optional
        True to noramlize each sample to 10k reads, False (default) to skip normalization
    random_seed : int, np.radnom.Generator instance or None, optional, default=None
        set the random number generator seed for the random permutations. Used to select subset of samples.
        If int, random_seed is the seed used by the random number generator;
        If Generator instance, random_seed is set to the random number generator;
        If None, then fresh, unpredictable entropy will be pulled from the OS    

    Returns
    -------
    exp: the joined experiment
    '''
    exp = None
    total_ok = 0
    total_low = 0
    for idx, cname in enumerate(glob.glob('../studies/*')):
        # Initialize the random seed for each study, since the order of studies is OS dependent
        rng = np.random.default_rng(random_seed)
        if os.path.isdir(cname):
            print('**********')
            print('processing %s (%d)' % (cname, idx))
            tables = glob.glob(os.path.join(cname,'all.*biom'))
            print(tables)
            if len(tables)==0:
                print('dir %s does not contain a biom table' % cname)
                continue
            bt=tables[0]
            if normalize is True:
                normalize=10000
            else:
                normalize = None
            data=ca.read_amplicon(os.path.join(bt),os.path.join(cname,'up.map.csv'),normalize=normalize,min_reads=1000)
            print('-------------')
            print(data)
            # TODO: if not enough samples, print and continue
            # if enough samples, keep only random subet
            if subset_size is not None:
                tt=data.filter_samples('type','HC')
                ns = len(tt.sample_metadata)
                if ns < subset_control:
                    print('not enough controls (%d). skipping' % ns)
                    if not keep_less:
                        total_low += 1
                        continue
                # randomly subsample
                rp = rng.permutation(ns)
                rp = rp[:subset_size]
                new_ids = [tt.sample_metadata['_sample_id'][x] for x in rp]
                # similar for disease
                tt=data.filter_samples('type','disease')
                ns = len(tt.sample_metadata)
                if ns < subset_size:
                    print('not enough disease (%d). skipping' % ns)
                    if not keep_less:
                        total_low += 1
                        continue
                # randomly subsample
                rp = np.random.permutation(ns)
                rp = rp[:subset_size]
                new_ids2 = [tt.sample_metadata['_sample_id'][x] for x in rp]
                # join the ids for the sick and controls
                all_ids = new_ids + new_ids2
                # and finally
                data = data.filter_samples('_sample_id',all_ids)
                print('keeping %d total samples' % len(data.sample_metadata))
            else:
                print('filtering for HC and disease')
                data = data.filter_samples('type', ['HC', 'disease'])
                print(data)
            data.description = cname
            if exp is None:
                exp = data
                exp.sample_metadata['exp']=cname
            else:
                exp = exp.join_experiments(data, field=cname)
                exp.sample_metadata.loc[exp.sample_metadata['exp'].isnull(),'exp']=cname
            total_ok += 1
    print('finished. Total processed %d. Total ok %d. Not enough samples %d' % (idx+1, total_ok, total_low))
    return exp

# %%
exp=join_all_exps(random_seed=2020)
# Out:
# **********
# processing ../studies/61 (0)
# ['../studies/61/all.biom']
# 2021-04-05 17:46:18 INFO loaded 41 samples, 2715 features
# 2021-04-05 17:46:18 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:18 INFO After filtering, 41 remain.
# -------------
# AmpliconExperiment with 41 samples, 2715 features
# not enough controls (21). skipping
# not enough disease (20). skipping
# keeping 41 total samples
# **********
# processing ../studies/59 (1)
# ['../studies/59/all.biom']
# 2021-04-05 17:46:18 INFO loaded 33 samples, 2637 features
# 2021-04-05 17:46:18 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:18 INFO After filtering, 33 remain.
# -------------
# AmpliconExperiment with 33 samples, 2637 features
# not enough controls (16). skipping
# not enough disease (17). skipping
# keeping 33 total samples
# **********
# processing ../studies/50 (2)
# ['../studies/50/all.biom']
# 2021-04-05 17:46:18 INFO loaded 58 samples, 959 features
# 2021-04-05 17:46:18 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:18 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 959 features
# keeping 46 total samples
# **********
# processing ../studies/57 (3)
# ['../studies/57/all.biom']
# 2021-04-05 17:46:19 INFO loaded 85 samples, 4058 features
# 2021-04-05 17:46:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:19 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 4058 features
# keeping 46 total samples
# **********
# processing ../studies/32 (4)
# ['../studies/32/all.biom']
# 2021-04-05 17:46:19 INFO loaded 43 samples, 1748 features
# 2021-04-05 17:46:19 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:19 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 1748 features
# not enough controls (13). skipping
# keeping 36 total samples
# **********
# processing ../studies/56 (5)
# ['../studies/56/all.biom']
# 2021-04-05 17:46:20 INFO loaded 43 samples, 3045 features
# 2021-04-05 17:46:20 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:20 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 3045 features
# not enough controls (22). skipping
# not enough disease (21). skipping
# keeping 43 total samples
# **********
# processing ../studies/51 (6)
# ['../studies/51/all.biom']
# 2021-04-05 17:46:21 INFO loaded 164 samples, 3240 features
# 2021-04-05 17:46:21 WARNING These have metadata but do not have data - dropped (2): {'SRR10430029', 'SRR10429951'}
# 2021-04-05 17:46:21 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:21 INFO After filtering, 164 remain.
# -------------
# AmpliconExperiment with 164 samples, 3240 features
# keeping 46 total samples
# **********
# processing ../studies/58 (8)
# ['../studies/58/all.biom']
# 2021-04-05 17:46:22 INFO loaded 45 samples, 3005 features
# 2021-04-05 17:46:22 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:22 INFO After filtering, 45 remain.
# -------------
# AmpliconExperiment with 45 samples, 3005 features
# not enough disease (22). skipping
# keeping 45 total samples
# **********
# processing ../studies/60 (9)
# ['../studies/60/all.biom']
# 2021-04-05 17:46:24 INFO loaded 73 samples, 3771 features
# 2021-04-05 17:46:24 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:24 INFO After filtering, 73 remain.
# -------------
# AmpliconExperiment with 73 samples, 3771 features
# keeping 46 total samples
# **********
# processing ../studies/34 (10)
# ['../studies/34/all.biom']
# 2021-04-05 17:46:26 INFO loaded 32 samples, 1234 features
# 2021-04-05 17:46:26 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:26 INFO After filtering, 32 remain.
# -------------
# AmpliconExperiment with 32 samples, 1234 features
# not enough controls (14). skipping
# not enough disease (18). skipping
# keeping 32 total samples
# **********
# processing ../studies/33 (11)
# ['../studies/33/all.biom']
# 2021-04-05 17:46:27 INFO loaded 58 samples, 1250 features
# 2021-04-05 17:46:27 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:27 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 1250 features
# not enough disease (19). skipping
# keeping 42 total samples
# **********
# processing ../studies/20 (12)
# ['../studies/20/all.biom']
# 2021-04-05 17:46:29 INFO loaded 174 samples, 1622 features
# 2021-04-05 17:46:29 WARNING These have metadata but do not have data - dropped (1): {'ERR2837004'}
# 2021-04-05 17:46:29 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:29 INFO After filtering, 151 remain.
# -------------
# AmpliconExperiment with 151 samples, 1622 features
# not enough disease (20). skipping
# keeping 43 total samples
# **********
# processing ../studies/18 (13)
# ['../studies/18/all.biom']
# 2021-04-05 17:46:31 INFO loaded 84 samples, 1183 features
# 2021-04-05 17:46:31 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:31 INFO After filtering, 84 remain.
# -------------
# AmpliconExperiment with 84 samples, 1183 features
# keeping 46 total samples
# **********
# processing ../studies/27 (14)
# ['../studies/27/all.biom']
# 2021-04-05 17:46:33 INFO loaded 251 samples, 1403 features
# 2021-04-05 17:46:33 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:33 INFO After filtering, 233 remain.
# -------------
# AmpliconExperiment with 233 samples, 1403 features
# keeping 46 total samples
# **********
# processing ../studies/9 (15)
# ['../studies/9/all.biom']
# 2021-04-05 17:46:35 INFO loaded 498 samples, 3722 features
# 2021-04-05 17:46:35 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:35 INFO After filtering, 497 remain.
# -------------
# AmpliconExperiment with 497 samples, 3722 features
# keeping 46 total samples
# **********
# processing ../studies/11 (16)
# ['../studies/11/all.biom']
# 2021-04-05 17:46:38 INFO loaded 109 samples, 2312 features
# 2021-04-05 17:46:38 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:38 INFO After filtering, 109 remain.
# -------------
# AmpliconExperiment with 109 samples, 2312 features
# keeping 46 total samples
# **********
# processing ../studies/7 (17)
# ['../studies/7/all.biom']
# 2021-04-05 17:46:41 INFO loaded 441 samples, 4403 features
# 2021-04-05 17:46:41 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:41 INFO After filtering, 441 remain.
# -------------
# AmpliconExperiment with 441 samples, 4403 features
# keeping 46 total samples
# **********
# processing ../studies/29 (18)
# ['../studies/29/all.biom']
# 2021-04-05 17:46:45 INFO loaded 595 samples, 3470 features
# 2021-04-05 17:46:45 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:45 INFO After filtering, 594 remain.
# -------------
# AmpliconExperiment with 594 samples, 3470 features
# keeping 46 total samples
# **********
# processing ../studies/16 (19)
# ['../studies/16/all.biom']
# 2021-04-05 17:46:49 INFO loaded 120 samples, 2116 features
# 2021-04-05 17:46:49 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:49 INFO After filtering, 119 remain.
# -------------
# AmpliconExperiment with 119 samples, 2116 features
# keeping 46 total samples
# **********
# processing ../studies/42 (20)
# ['../studies/42/all.biom']
# 2021-04-05 17:46:54 INFO loaded 99 samples, 3829 features
# 2021-04-05 17:46:54 WARNING These have metadata but do not have data - dropped (6): {'ERR1073898', 'ERR1315870', 'ERR1841805', 'ERR1417474', 'ERR2696902', 'ERR1545879'}
# 2021-04-05 17:46:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:46:54 INFO After filtering, 96 remain.
# -------------
# AmpliconExperiment with 96 samples, 3829 features
# keeping 46 total samples
# **********
# processing ../studies/45 (21)
# ['../studies/45/all.biom']
# 2021-04-05 17:47:00 INFO loaded 1095 samples, 14981 features
# 2021-04-05 17:47:00 WARNING These have metadata but do not have data - dropped (66): {'ERR1091564', 'ERR1545831', 'ERR1545996', 'ERR1545778', 'ERR1841761', 'ERR1389884', 'ERR2238631', 'ERR2239656', 'ERR1072642', 'ERR1841758', 'ERR1841817', 'ERR1075171', 'ERR1545722', 'ERR1545752', 'ERR1090995', 'ERR2318028', 'ERR1091321', 'ERR2303979', 'ERR1545981', 'ERR1545967', 'ERR1841716', 'ERR1073742', 'ERR1545883', 'ERR1160652', 'ERR1091606', 'ERR1841810', 'ERR1316257', 'ERR1545905', 'ERR2239754', 'ERR1546017', 'ERR1160500', 'ERR1545998', 'ERR1091145', 'ERR1841815', 'ERR1545894', 'ERR2239633', 'ERR1841814', 'ERR1841492', 'ERR1389937', 'ERR2238647', 'ERR1091364', 'ERR1090798', 'ERR1545957', 'ERR1841804', 'ERR1545906', 'ERR2696527', 'ERR1091654', 'ERR1091156', 'ERR1546023', 'ERR1545847', 'ERR2239699', 'ERR1074008', 'ERR1160588', 'ERR1089803', 'ERR1074155', 'ERR1545935', 'ERR1841512', 'ERR1075099', 'ERR1545921', 'ERR1459053', 'ERR1073096', 'ERR1091590', 'ERR1545915', 'ERR1073328', 'ERR1545994', 'ERR1160532'}
# 2021-04-05 17:47:01 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:47:01 INFO After filtering, 1043 remain.
# -------------
# AmpliconExperiment with 1043 samples, 14981 features
# keeping 46 total samples
# **********
# processing ../studies/6 (22)
# ['../studies/6/all.biom']
# 2021-04-05 17:47:19 INFO loaded 620 samples, 4175 features
# 2021-04-05 17:47:19 WARNING These have metadata but do not have data - dropped (4): {'ERR3519122', 'ERR3520757', 'ERR3520666', 'ERR3520927'}
# 2021-04-05 17:47:20 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:47:20 INFO After filtering, 612 remain.
# -------------
# AmpliconExperiment with 612 samples, 4175 features
# keeping 46 total samples
# **********
# processing ../studies/28 (23)
# ['../studies/28/all.biom']
# 2021-04-05 17:47:37 INFO loaded 142 samples, 1306 features
# 2021-04-05 17:47:37 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:47:37 INFO After filtering, 135 remain.
# -------------
# AmpliconExperiment with 135 samples, 1306 features
# keeping 46 total samples
# **********
# processing ../studies/17 (24)
# ['../studies/17/all.biom']
# 2021-04-05 17:47:54 INFO loaded 50 samples, 2307 features
# 2021-04-05 17:47:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:47:54 INFO After filtering, 50 remain.
# -------------
# AmpliconExperiment with 50 samples, 2307 features
# keeping 46 total samples
# **********
# processing ../studies/1 (25)
# ['../studies/1/all.biom']
# 2021-04-05 17:48:12 INFO loaded 38 samples, 1082 features
# 2021-04-05 17:48:12 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:48:12 INFO After filtering, 38 remain.
# -------------
# AmpliconExperiment with 38 samples, 1082 features
# not enough controls (20). skipping
# not enough disease (18). skipping
# keeping 38 total samples
# **********
# processing ../studies/10 (26)
# ['../studies/10/all.biom']
# 2021-04-05 17:48:31 INFO loaded 174 samples, 3295 features
# 2021-04-05 17:48:31 WARNING These have metadata but do not have data - dropped (2): {'SRR1689253', 'SRR1687461'}
# 2021-04-05 17:48:31 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:48:31 INFO After filtering, 174 remain.
# -------------
# AmpliconExperiment with 174 samples, 3295 features
# keeping 46 total samples
# **********
# processing ../studies/19 (27)
# ['../studies/19/all.biom']
# 2021-04-05 17:48:54 INFO loaded 68 samples, 1401 features
# 2021-04-05 17:48:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:48:54 INFO After filtering, 68 remain.
# -------------
# AmpliconExperiment with 68 samples, 1401 features
# keeping 46 total samples
# **********
# processing ../studies/26 (28)
# ['../studies/26/all.biom']
# 2021-04-05 17:49:13 INFO loaded 1388 samples, 11834 features
# 2021-04-05 17:49:13 WARNING These have metadata but do not have data - dropped (41): {'DB3.234', 'DB3.229', 'DB3.223', 'DB3.218', 'DB3.196', 'DB3.228', 'DB2.239', 'DB3.230', 'DB3.269', 'DB3.110', 'DB3.072', 'DB3.036', 'DB3.251', 'DB3.047', 'DB3.071', 'DB3.239', 'DB3.250', 'DB3.102', 'DB3.108', 'DB2.241', 'DB2.135', 'DB3.101', 'DB3.217', 'DB3.109', 'DB3.212', 'DB2.245', 'DB3.078', 'DB3.096', 'DB3.106', 'DB2.242', 'DB2.240', 'DB3.107', 'DB3.103', 'DB3.104', 'DB2.076', 'DB3.231', 'DB3.266', 'DB2.069', 'DB3.265', 'DB3.219', 'DB3.264'}
# 2021-04-05 17:49:13 WARNING These have data but do not have metadata: {'DB7.163', 'DB8.224', 'DB8.075', 'DB4.253', 'DB6.279', 'DB6.145', 'DB7.134', 'DB4.062', 'DB5.281', 'DB8.235', 'DB4.233', 'DB8.071', 'DB8.206', 'DB4.053', 'DB5.167', 'DB8.143', 'DB4.230', 'DB8.027', 'DB7.007', 'DB6.282', 'DB5.289', 'DB7.194', 'DB7.158', 'DB7.202', 'DB7.107', 'DB6.114', 'DB8.174', 'DB4.049', 'DB5.028', 'DB6.101', 'DB8.004', 'DB4.005', 'DB5.115', 'DB7.023', 'DB4.100', 'DB6.246', 'DB5.026', 'DB8.105', 'DB7.079', 'DB4.067', 'DB5.119', 'DB8.001', 'DB5.143', 'DB6.218', 'DB7.196', 'DB7.172', 'DB6.213', 'DB6.115', 'DB8.155', 'DB4.050', 'DB4.202', 'DB6.193', 'DB5.139', 'DB8.248', 'DB8.247', 'DB5.227', 'DB6.078', 'DB8.018', 'DB5.053', 'DB5.070', 'DB7.074', 'DB7.253
# 2021-04-05 17:51:10 WARNING These have metadata but do not have data - dropped (64): {'ERR1545911', 'ERR1160673', 'ERR1545891', 'ERR1090161', 'ERR1545962', 'ERR1545986', 'ERR1545978', 'ERR1091354', 'ERR1089679', 'ERR1545802', 'ERR1074779', 'ERR1091155', 'ERR1545907', 'ERR1841813', 'ERR1075185', 'ERR1545774', 'ERR1074050', 'ERR1074092', 'ERR1545804', 'ERR1074007', 'ERR1160680', 'ERR1546016', 'ERR1072778', 'ERR1841525', 'ERR1597274', 'ERR1073198', 'ERR1089814', 'ERR1545780', 'ERR1074974', 'ERR1075896', 'ERR1073883', 'ERR1073330', 'ERR1075069', 'ERR1842199', 'ERR1545963', 'ERR1075272', 'ERR1546010', 'ERR2239717', 'ERR1074978', 'ERR1545939', 'ERR1545936', 'ERR1074005', 'ERR1072979', 'ERR1091147', 'ERR1545877', 'ERR2242158', 'ERR1080384', 'ERR1545747', 'ERR1545781', 'ERR1160475', 'ERR1074955', 'ERR1389624', 'ERR1545838', 'ERR1072794', 'ERR1545833', 'ERR1545990', 'ERR1545702', 'ERR1545803', 'ERR1546057', 'ERR1597126', 'ERR1389819', 'ERR1075071', 'ERR1072781', 'ERR1075286'}
# 2021-04-05 17:51:11 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:51:11 INFO After filtering, 835 remain.
# -------------
# AmpliconExperiment with 835 samples, 11915 features
# keeping 46 total samples
# **********
# processing ../studies/43 (32)
# ['../studies/43/all.biom']
# 2021-04-05 17:52:14 INFO loaded 91 samples, 3426 features
# 2021-04-05 17:52:14 WARNING These have metadata but do not have data - dropped (9): {'ERR1545914', 'ERR1545813', 'ERR1075067', 'ERR1545849', 'ERR1841752', 'ERR1545876', 'ERR2239660', 'ERR1841803', 'ERR1073734'}
# 2021-04-05 17:52:14 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:52:14 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 3426 features
# keeping 46 total samples
# **********
# processing ../studies/36 (33)
# ['../studies/36/all.biom']
# 2021-04-05 17:53:09 INFO loaded 16 samples, 1191 features
# 2021-04-05 17:53:09 WARNING These have metadata but do not have data - dropped (1): {'ERR1089974'}
# 2021-04-05 17:53:09 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:53:09 INFO After filtering, 15 remain.
# -------------
# AmpliconExperiment with 15 samples, 1191 features
# not enough controls (9). skipping
# not enough disease (6). skipping
# keeping 15 total samples
# **********
# processing ../studies/31 (34)
# ['../studies/31/all.biom']
# 2021-04-05 17:54:00 INFO loaded 70 samples, 1929 features
# 2021-04-05 17:54:00 WARNING These have metadata but do not have data - dropped (18): {'ERR1331868', 'ERR1331858', 'ERR1331856', 'ERR1331867', 'ERR1331866', 'ERR1331871', 'ERR1331872', 'ERR1331865', 'ERR1331860', 'ERR1331869', 'ERR1331870', 'ERR1331864', 'ERR1331863', 'ERR1331862', 'ERR1331859', 'ERR1331861', 'ERR1331814', 'ERR1331857'}
# 2021-04-05 17:54:00 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:54:00 INFO After filtering, 70 remain.
# -------------
# AmpliconExperiment with 70 samples, 1929 features
# keeping 46 total samples
# **********
# processing ../studies/62 (35)
# ['../studies/62/all.biom']
# 2021-04-05 17:54:47 INFO loaded 196 samples, 5813 features
# 2021-04-05 17:54:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17
WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 17:58:54 INFO After filtering, 587 remain.
# -------------
# AmpliconExperiment with 587 samples, 10422 features
# keeping 46 total samples
# **********
# processing ../studies/52 (40)
# ['../studies/52/all.biom']
# 2021-04-05 18:00:07 INFO loaded 30 samples, 2580 features
# 2021-04-05 18:00:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:00:07 INFO After filtering, 30 remain.
# -------------
# AmpliconExperiment with 30 samples, 2580 features
# not enough controls (17). skipping
# not enough disease (13). skipping
# keeping 30 total samples
# **********
# processing ../studies/55 (41)
# ['../studies/55/all.biom']
# 2021-04-05 18:01:05 INFO loaded 74 samples, 3939 features
# 2021-04-05 18:01:05 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:01:05 INFO After filtering, 74 remain.
# -------------
# AmpliconExperiment with 74 samples, 3939 features
# keeping 46 total samples
# **********
# processing ../studies/46 (42)
# ['../studies/46/all.biom']
# 2021-04-05 18:02:04 INFO loaded 584 samples, 10980 features
# 2021-04-05 18:02:04 WARNING These have metadata but do not have data - dropped (41): {'ERR1545904', 'ERR2238718', 'ERR1075338', 'ERR2239702', 'ERR1073073', 'ERR1545701', 'ERR1077699', 'ERR1546003', 'ERR1089788', 'ERR1545968', 'ERR1459007', 'ERR1546040', 'ERR1854779', 'ERR1075243', 'ERR2304178', 'ERR1841755', 'ERR1074261', 'ERR1074885', 'ERR1841818', 'ERR1074071', 'ERR1080238', 'ERR1545694', 'ERR1841546', 'ERR1089939', 'ERR1075226', 'ERR1545678', 'ERR1545890', 'ERR1545910', 'ERR1073933', 'ERR1545902', 'ERR1545916', 'ERR2239804', 'ERR1073802', 'ERR1546027', 'ERR1073744', 'ERR1545859', 'ERR1389664', 'ERR1545965', 'ERR2242536', 'ERR2239582', 'ERR1545961'}
# 2021-04-05 18:02:04 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:02:04 INFO After filtering, 554 remain.
# -------------
# AmpliconExperiment with 554 samples, 10980 features
# keeping 46 total samples
# **********
# processing ../studies/41 (43)
# ['../studies/41/all.biom']
# 2021-04-05 18:03:23 INFO loaded 84 samples, 3557 features
# 2021-04-05 18:03:23 WARNING These have metadata but do not have data - dropped (5): {'ERR1075045', 'ERR2238709', 'ERR1545772', 'ERR1160360', 'ERR2238703'}
# 2021-04-05 18:03:23 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:03:23 INFO After filtering, 80 remain.
# -------------
# AmpliconExperiment with 80 samples, 3557 features
# keeping 46 total samples
# **********
# processing ../studies/48 (44)
# ['../studies/48/all.biom']
# 2021-04-05 18:04:21 INFO loaded 293 samples, 6184 features
# 2021-04-05 18:04:21 WARNING These have metadata but do not have data - dropped (21): {'ERR2239290', 'ERR1075875', 'ERR1090826', 'ERR1545775', 'ERR1545869', 'ERR2308577', 'ERR1545878', 'ERR1160560', 'ERR2238646', 'ERR1841718', 'ERR1075817', 'ERR1089851', 'ERR1091689', 'ERR1546021', 'ERR1546022', 'ERR1089874', 'ERR1073280', 'ERR1089880', 'ERR2033565', 'ERR1091390', 'ERR1841798'}
# 2021-04-05 18:04:21 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:04:21 INFO After filtering, 280 remain.
# -------------
# AmpliconExperiment with 280 samples, 6184 features
# keeping 46 total samples
# **********
# processing ../studies/24 (45)
# ['../studies/24/all.biom']
# 2021-04-05 18:05:15 INFO loaded 25 samples, 999 features
# 2021-04-05 18:05:15 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:05:15 INFO After filtering, 25 remain.
# -------------
# AmpliconExperiment with 25 samples, 999 features
# not enough controls (10). skipping
# not enough disease (15). skipping
# keeping 25 total samples
# **********
# processing ../studies/23 (46)
# ['../studies/23/all.biom']
# 2021-04-05 18:06:02 INFO loaded 114 samples, 1867 features
# 2021-04-05 18:06:02 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:06:02 INFO After filtering, 114 remain.
# -------------
# AmpliconExperiment with 114 samples, 1867 features
# keeping 46 total samples
# **********
# processing ../studies/4 (47)
# ['../studies/4/all.biom']
# 2021-04-05 18:06:54 INFO loaded 83 samples, 1652 features
# 2021-04-05 18:06:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:06:54 INFO After filtering, 82 remain.
# -------------
# AmpliconExperiment with 82 samples, 1652 features
# keeping 46 total samples
# **********
# processing ../studies/15 (48)
# ['../studies/15/all.biom']
# 2021-04-05 18:07:47 INFO loaded 174 samples, 2103 features
# 2021-04-05 18:07:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:07:47 INFO After filtering, 162 remain.
# -------------
# AmpliconExperiment with 162 samples, 2103 features
# keeping 46 total samples
# **********
# processing ../studies/3 (49)
# ['../studies/3/all.biom']
# 2021-04-05 18:08:41 INFO loaded 337 samples, 3021 features
# 2021-04-05 18:08:41 WARNING These have metadata but do not have data - dropped (11): {'ERR1513792', 'ERR1513697', 'ERR1513809', 'ERR1513852', 'ERR1513897', 'ERR1513791', 'ERR1513823', 'ERR1513668', 'ERR1513848', 'ERR1513720', 'ERR1513893'}
# 2021-04-05 18:08:41 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:08:41 INFO After filtering, 334 remain.
# -------------
# AmpliconExperiment with 334 samples, 3021 features
# keeping 46 total samples
# **********
# processing ../studies/12 (50)
# ['../studies/12/all.biom']
# 2021-04-05 18:09:36 INFO loaded 2664 samples, 13732 features
# 2021-04-05 18:09:36 WARNING These have data but do not have metadata: {'DB7.163', 'DB9.089', 'DB3.063', 'DB3.117', 'DB4.253', 'DB6.279', 'DB10.263', 'DB2.134', 'DB4.062', 'DB8.235', 'DB10.105', 'DB4.233', 'DB3.053', 'DB9.253', 'DB4.053', 'DB8.206', 'DB8.143', 'DB6.282', 'DB9.110', 'DB5.289', 'DB2.092', 'DB3.107', 'DB7.158', 'DB8.174', 'DB4.049', 'DB2.030', 'DB5.028', 'DB1.270', 'DB8.004', 'DB6.246', 'DB10.269', 'DB7.079', 'DB2.122', 'DB4.067', 'DB9.091', 'DB5.003', 'DB8.001', 'DB3.026', 'DB5.143', 'DB6.218', 'DB9.188', 'DB6.213', 'DB9.283', 'DB8.155', 'DB10.014', 'DB4.050', 'DB6.193', 'DB9.291', 'DB2.222', 'DB8.247', 'DB5.227', 'DB2.025', 'DB10.170', 'DB3.004', 'DB8.018', 'DB10.053', 'DB2.009', 'DB9.144', 'DB2.149', 'DB3.116', 'DB7.074', 'DB7.253', 'DB10.132', 'DB6.230', 'DB3.157', 'DB10.282', 'DB6.029', 'DB9.194', 'DB9.154', 'DB3.166', 'DB9.216', '
WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:16:10 INFO After filtering, 333 remain.
# -------------
# AmpliconExperiment with 333 samples, 4664 features
# keeping 46 total samples
# **********
# processing ../studies/14 (58)
# ['../studies/14/all.biom']
# 2021-04-05 18:17:25 INFO loaded 123 samples, 1271 features
# 2021-04-05 18:17:25 WARNING These have metadata but do not have data - dropped (57): {'SRR6804656', 'SRR6307733', 'SRR6804663', 'SRR6804657', 'SRR6307712', 'SRR6307779', 'SRR6307775', 'SRR6307789', 'SRR6307795', 'SRR6307780', 'SRR6804660', 'SRR6307756', 'SRR6307788', 'SRR6307794', 'SRR6307777', 'SRR6307759', 'SRR6307781', 'SRR6307790', 'SRR6804661', 'SRR6307774', 'SRR6804665', 'SRR6307796', 'SRR6307792', 'SRR6307734', 'SRR6307714', 'SRR6804653', 'SRR6804654', 'SRR6804655', 'SRR6307716', 'SRR6307797', 'SRR6307721', 'SRR6307778', 'SRR6307791', 'SRR6804666', 'SRR6307755', 'SRR6307776', 'SRR6804652', 'SRR6307750', 'SRR6307757', 'SRR6307717', 'SRR6307718', 'SRR6804664', 'SRR6804658', 'SRR6307713', 'SRR6307758', 'SRR6307719', 'SRR6307773', 'SRR6804659', 'SRR6307715', 'SRR6307760', 'SRR6307793', 'SRR6307753', 'SRR6804662', 'SRR6307720', 'SRR6307782', 'SRR6307754', 'SRR6307751'}
# 2021-04-05 18:17:25 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:17:25 INFO After filtering, 123 remain.
# -------------
# AmpliconExperiment with 123 samples, 1271 features
# keeping 46 total samples
# **********
# processing ../studies/22 (59)
# ['../studies/22/all.biom']
# 2021-04-05 18:18:34 INFO loaded 144 samples, 2687 features
# 2021-04-05 18:18:34 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:18:34 INFO After filtering, 144 remain.
# -------------
# AmpliconExperiment with 144 samples, 2687 features
# keeping 46 total samples
# **********
# processing ../studies/25 (61)
# ['../studies/25/all.biom']
# 2021-04-05 18:19:48 INFO loaded 92 samples, 1781 features
# 2021-04-05 18:19:48 WARNING These have metadata but do not have data - dropped (1): {'ERR1776941'}
# 2021-04-05 18:19:48 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 18:19:48 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 1781 features
# not enough disease (20). skipping
# keeping 43 total samples
# finished. Total processed 62. Total ok 59. Not enough samples 0

# %%
exp.description='merged'
exp
# Out:
# AmpliconExperiment ("merged") with 2533 samples, 44537 features

# %%
exp.sample_metadata
# Out:
#                type disease_cohort    age  _sample_id  \
# ERR1385491  disease            T2D  adult  ERR1385491
# ERR1385206       HC            T2D  adult  ERR1385206
# ERR1383735  disease            T2D  adult  ERR1383735
# ERR1384980  disease            T2D  adult  ERR1384980
# ERR1382783       HC            T2D  adult  ERR1382783
# ...             ...            ...    ...         ...
# ERR1776911  disease            NaN  child  ERR1776911
# ERR1776929  disease            NaN  child  ERR1776929
# ERR1776938       HC            NaN  adult  ERR1776938
# ERR1776947  disease            NaN  child  ERR1776947
# ERR1776954  disease            NaN  child  ERR1776954
#
#             _calour_original_abundance            exp ../studies/59  \
# ERR1385491                     68395.0  ../studies/61           exp
# ERR1385206                     95408.0  ../studies/61           exp
# ERR1383735                     60137.0  ../studies/61           exp
# ERR1384980                     74487.0  ../studies/61           exp
# ERR1382783                     48282.0  ../studies/61           exp
# ...                                ...            ...           ...
# ERR1776911                      4943.0  ../studies/25           NaN
# ERR1776929                     27155.0  ../studies/25           NaN
# ERR1776938                      4227.0  ../studies/25           NaN
# ERR1776947                     10203.0  ../studies/25           NaN
# ERR1776954                     32712.0  ../studies/25           NaN
#
#            host_subject title host_sex  ... ../studies/13 Isolation_source  \
# ERR1385491          NaN   NaN      NaN  ...           exp              NaN
# ERR1385206          NaN   NaN      NaN  ...           exp              NaN
# ERR1383735          NaN   NaN      NaN  ...           exp              NaN
# ERR1384980          NaN   NaN      NaN  ...           exp              NaN
# ERR1382783          NaN   NaN      NaN  ...           exp              NaN
# ...                 ...   ...      ...  ...           ...              ...
# ERR1776911          NaN   NaN      NaN  ...           NaN              NaN
# ERR1776929          NaN   NaN      NaN  ...           NaN              NaN
# ERR1776938          NaN   NaN      NaN  ...           NaN              NaN
# ERR1776947          NaN   NaN      NaN  ...           NaN              NaN
# ERR1776954          NaN   NaN      NaN  ...           NaN              NaN
#
#            sequencing_lab ../studies/5 ../studies/14  ../studies/22  Sample  \
# ERR1385491            NaN          exp           exp            exp     NaN
# ERR1385206            NaN          exp           exp            exp     NaN
# ERR1383735            NaN          exp           exp            exp     NaN
# ERR1384980            NaN          exp           exp            exp     NaN
# ERR1382783            NaN          exp           exp            exp     NaN
# ...                   ...          ...           ...            ...     ...
# ERR1776911            NaN          NaN           NaN            NaN     S74
# ERR1776929            NaN          NaN           NaN            NaN     S80
# ERR1776938            NaN          NaN           NaN            NaN     S84
# ERR1776947            NaN          NaN           NaN            NaN     S88
# ERR1776954            NaN          NaN           NaN            NaN     S90
#
#             rep             sample_type ../studies/25
# ERR1385491  NaN                     NaN           exp
# ERR1385206  NaN                     NaN           exp
# ERR1383735  NaN                     NaN           exp
# ERR1384980  NaN                     NaN           exp
# ERR1382783  NaN                     NaN           exp
# ...         ...                     ...           ...
# ERR1776911    a  Crohn_at _start_of_EEN         other
# ERR1776929    c  Crohn_at _start_of_EEN         other
# ERR1776938    a         Relative_mother         other
# ERR1776947    a  Crohn_at _start_of_EEN         other
# ERR1776954    b  Crohn_at _start_of_EEN         other
#
# [2533 rows x 344 columns]

# %% [markdown]
# ## Save the resulting biom table and mapping file

# %%
exp.save('../allsamples/allsamples')
# Out:
# 2021-04-05 18:21:04 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %%
exp.save_fasta('../allsamples/allsamples.fa')

# %%
exp
# Out:
# AmpliconExperiment ("merged") with 2533 samples, 44537 features

# %% [markdown]
# ## Also save after filtering for blooiming bacteria

# %%
exp=exp.filter_by_fasta('../allsamples/blooming-bacteria.fa',negate=True)

# %%
exp.save('../allsamples/allsamples-no-bloom')
# Out:
# 2021-04-05 18:21:10 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %%
exp.save_fasta('../allsamples/allsamples-no-bloom.fa')

# %%
exp
# Out:
# AmpliconExperiment ("merged") with 2533 samples, 44526 features

# %% [markdown]
# # Now create the single biom table for all samples without subsampling

# %%
expall=join_all_exps(subset_size=None, random_seed=2020)
# Out:
# **********
# processing ../studies/61 (0)
# ['../studies/61/all.biom']
# 2021-04-05 19:56:44 INFO loaded 41 samples, 2715 features
# 2021-04-05 19:56:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:44 INFO After filtering, 41 remain.
# -------------
# AmpliconExperiment with 41 samples, 2715 features
# filtering for HC and disease
# AmpliconExperiment with 41 samples, 2715 features
# **********
# processing ../studies/59 (1)
# ['../studies/59/all.biom']
# 2021-04-05 19:56:44 INFO loaded 33 samples, 2637 features
# 2021-04-05 19:56:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:44 INFO After filtering, 33 remain.
# -------------
# AmpliconExperiment with 33 samples, 2637 features
# filtering for HC and disease
# AmpliconExperiment with 33 samples, 2637 features
# **********
# processing ../studies/50 (2)
# ['../studies/50/all.biom']
# 2021-04-05 19:56:44 INFO loaded 58 samples, 959 features
# 2021-04-05 19:56:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:44 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 959 features
# filtering for HC and disease
# AmpliconExperiment with 58 samples, 959 features
# **********
# processing ../studies/57 (3)
# ['../studies/57/all.biom']
# 2021-04-05 19:56:44 INFO loaded 85 samples, 4058 features
# 2021-04-05 19:56:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:44 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 4058 features
# filtering for HC and disease
# AmpliconExperiment with 85 samples, 4058 features
# **********
# processing ../studies/32 (4)
# ['../studies/32/all.biom']
# 2021-04-05 19:56:45 INFO loaded 43 samples, 1748 features
# 2021-04-05 19:56:45 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:45 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 1748 features
# filtering for HC and disease
# AmpliconExperiment with 43 samples, 1748 features
# **********
# processing ../studies/56 (5)
# ['../studies/56/all.biom']
# 2021-04-05 19:56:46 INFO loaded 43 samples, 3045 features
# 2021-04-05 19:56:46 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:46 INFO After filtering, 43 remain.
# -------------
# AmpliconExperiment with 43 samples, 3045 features
# filtering for HC and disease
# AmpliconExperiment with 43 samples, 3045 features
# **********
# processing ../studies/51 (6)
# ['../studies/51/all.biom']
# 2021-04-05 19:56:47 INFO loaded 164 samples, 3240 features
# 2021-04-05 19:56:47 WARNING These have metadata but do not have data - dropped (2): {'SRR10430029', 'SRR10429951'}
# 2021-04-05 19:56:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:47 INFO After filtering, 164 remain.
# -------------
# AmpliconExperiment with 164 samples, 3240 features
# filtering for HC and disease
# AmpliconExperiment with 164 samples, 3240 features
# **********
# processing ../studies/58 (8)
# ['../studies/58/all.biom']
# 2021-04-05 19:56:48 INFO loaded 45 samples, 3005 features
# 2021-04-05 19:56:48 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:48 INFO After filtering, 45 remain.
# -------------
# AmpliconExperiment with 45 samples, 3005 features
# filtering for HC and disease
# AmpliconExperiment with 45 samples, 3005 features
# **********
# processing ../studies/60 (9)
# ['../studies/60/all.biom']
# 2021-04-05 19:56:49 INFO loaded 73 samples, 3771 features
# 2021-04-05 19:56:49 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:49 INFO After filtering, 73 remain.
# -------------
# AmpliconExperiment with 73 samples, 3771 features
# filtering for HC and disease
# AmpliconExperiment with 73 samples, 3771 features
# **********
# processing ../studies/34 (10)
# ['../studies/34/all.biom']
# 2021-04-05 19:56:50 INFO loaded 32 samples, 1234 features
# 2021-04-05 19:56:50 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:50 INFO After filtering, 32 remain.
# -------------
# AmpliconExperiment with 32 samples, 1234 features
# filtering for HC and disease
# AmpliconExperiment with 32 samples, 1234 features
# **********
# processing ../studies/33 (11)
# ['../studies/33/all.biom']
# 2021-04-05 19:56:52 INFO loaded 58 samples, 1250 features
# 2021-04-05 19:56:52 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:52 INFO After filtering, 58 remain.
# -------------
# AmpliconExperiment with 58 samples, 1250 features
# filtering for HC and disease
# AmpliconExperiment with 58 samples, 1250 features
# **********
# processing ../studies/20 (12)
# ['../studies/20/all.biom']
# 2021-04-05 19:56:53 INFO loaded 174 samples, 1622 features
# 2021-04-05 19:56:53 WARNING These have metadata but do not have data - dropped (1): {'ERR2837004'}
# 2021-04-05 19:56:53 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:53 INFO After filtering, 151 remain.
# -------------
# AmpliconExperiment with 151 samples, 1622 features
# filtering for HC and disease
# AmpliconExperiment with 151 samples, 1622 features
# **********
# processing ../studies/18 (13)
# ['../studies/18/all.biom']
# 2021-04-05 19:56:55 INFO loaded 84 samples, 1183 features
# 2021-04-05 19:56:55 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:55 INFO After filtering, 84 remain.
# -------------
# AmpliconExperiment with 84 samples, 1183 features
# filtering for HC and disease
# AmpliconExperiment with 84 samples, 1183 features
# **********
# processing ../studies/27 (14)
# ['../studies/27/all.biom']
# 2021-04-05 19:56:57 INFO loaded 251 samples, 1403 features
# 2021-04-05 19:56:57 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:57 INFO After filtering, 233 remain.
# -------------
# AmpliconExperiment with 233 samples, 1403 features
# filtering for HC and disease
# AmpliconExperiment with 233 samples, 1403 features
# **********
# processing ../studies/9 (15)
# ['../studies/9/all.biom']
# 2021-04-05 19:56:59 INFO loaded 498 samples, 3722 features
# 2021-04-05 19:56:59 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:56:59 INFO After filtering, 497 remain.
# -------------
# AmpliconExperiment with 497 samples, 3722 features
# filtering for HC and disease
# AmpliconExperiment with 451 samples, 3722 features
# **********
# processing ../studies/11 (16)
# ['../studies/11/all.biom']
# 2021-04-05 19:57:01 INFO loaded 109 samples, 2312 features
# 2021-04-05 19:57:01 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:01 INFO After filtering, 109 remain.
# -------------
# AmpliconExperiment with 109 samples, 2312 features
# filtering for HC and disease
# AmpliconExperiment with 109 samples, 2312 features
# **********
# processing ../studies/7 (17)
# ['../studies/7/all.biom']
# 2021-04-05 19:57:04 INFO loaded 441 samples, 4403 features
# 2021-04-05 19:57:04 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:04 INFO After filtering, 441 remain.
# -------------
# AmpliconExperiment with 441 samples, 4403 features
# filtering for HC and disease
# AmpliconExperiment with 441 samples, 4403 features
# **********
# processing ../studies/29 (18)
# ['../studies/29/all.biom']
# 2021-04-05 19:57:08 INFO loaded 595 samples, 3470 features
# 2021-04-05 19:57:08 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:08 INFO After filtering, 594 remain.
# -------------
# AmpliconExperiment with 594 samples, 3470 features
# filtering for HC and disease
# AmpliconExperiment with 594 samples, 3470 features
# **********
# processing ../studies/16 (19)
# ['../studies/16/all.biom']
# 2021-04-05 19:57:12 INFO loaded 120 samples, 2116 features
# 2021-04-05 19:57:12 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:12 INFO After filtering, 119 remain.
# -------------
# AmpliconExperiment with 119 samples, 2116 features
# filtering for HC and disease
# AmpliconExperiment with 119 samples, 2116 features
# **********
# processing ../studies/42 (20)
# ['../studies/42/all.biom']
# 2021-04-05 19:57:17 INFO loaded 99 samples, 3829 features
# 2021-04-05 19:57:17 WARNING These have metadata but do not have data - dropped (6): {'ERR1073898', 'ERR1315870', 'ERR1841805', 'ERR1417474', 'ERR2696902', 'ERR1545879'}
# 2021-04-05 19:57:17 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:17 INFO After filtering, 96 remain.
# -------------
# AmpliconExperiment with 96 samples, 3829 features
# filtering for HC and disease
# AmpliconExperiment with 96 samples, 3829 features
# **********
# processing ../studies/45 (21)
# ['../studies/45/all.biom']
# 2021-04-05 19:57:24 INFO loaded 1095 samples, 14981 features
# 2021-04-05 19:57:24 WARNING These have metadata but do not have data - dropped (66): {'ERR1091564', 'ERR1545831', 'ERR1545996', 'ERR1545778', 'ERR1841761', 'ERR1389884', 'ERR2238631', 'ERR2239656', 'ERR1072642', 'ERR1841758', 'ERR1841817', 'ERR1075171', 'ERR1545722', 'ERR1545752', 'ERR1090995', 'ERR2318028', 'ERR1091321', 'ERR2303979', 'ERR1545981', 'ERR1545967', 'ERR1841716', 'ERR1073742', 'ERR1545883', 'ERR1160652', 'ERR1091606', 'ERR1841810', 'ERR1316257', 'ERR1545905', 'ERR2239754', 'ERR1546017', 'ERR1160500', 'ERR1545998', 'ERR1091145', 'ERR1841815', 'ERR1545894', 'ERR2239633', 'ERR1841814', 'ERR1841492', 'ERR1389937', 'ERR2238647', 'ERR1091364', 'ERR1090798', 'ERR1545957', 'ERR1841804', 'ERR1545906', 'ERR2696527', 'ERR1091654', 'ERR1091156', 'ERR1546023', 'ERR1545847', 'ERR2239699', 'ERR1074008', 'ERR1160588', 'ERR1089803', 'ERR1074155', 'ERR1545935', 'ERR1841512', 'ERR1075099', 'ERR1545921', 'ERR1459053', 'ERR1073096', 'ERR1091590', 'ERR1545915', 'ERR1073328', 'ERR1545994', 'ERR1160532'}
# 2021-04-05 19:57:25 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:25 INFO After filtering, 1043 remain.
# -------------
# AmpliconExperiment with 1043 samples, 14981 features
# filtering for HC and disease
# AmpliconExperiment with 1043 samples, 14981 features
# **********
# processing ../studies/6 (22)
# ['../studies/6/all.biom']
# 2021-04-05 19:57:44 INFO loaded 620 samples, 4175 features
# 2021-04-05 19:57:44 WARNING These have metadata but do not have data - dropped (4): {'ERR3519122', 'ERR3520757', 'ERR3520666', 'ERR3520927'}
# 2021-04-05 19:57:44 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:57:44 INFO After filtering, 612 remain.
# -------------
# AmpliconExperiment with 612 samples, 4175 features
# filtering for HC and disease
# AmpliconExperiment with 612 samples, 4175 features
# **********
# processing ../studies/28 (23)
# ['../studies/28/all.biom']
# 2021-04-05 19:58:01 INFO loaded 142 samples, 1306 features
# 2021-04-05 19:58:01 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:58:01 INFO After filtering, 135 remain.
# -------------
# AmpliconExperiment with 135 samples, 1306 features
# filtering for HC and disease
# AmpliconExperiment with 135 samples, 1306 features
# **********
# processing ../studies/17 (24)
# ['../studies/17/all.biom']
# 2021-04-05 19:58:17 INFO loaded 50 samples, 2307 features
# 2021-04-05 19:58:17 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:58:17 INFO After filtering, 50 remain.
# -------------
# AmpliconExperiment with 50 samples, 2307 features
# filtering for HC and disease
# AmpliconExperiment with 50 samples, 2307 features
# **********
# processing ../studies/1 (25)
# ['../studies/1/all.biom']
# 2021-04-05 19:58:34 INFO loaded 38 samples, 1082 features
# 2021-04-05 19:58:34 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:58:34 INFO After filtering, 38 remain.
# -------------
# AmpliconExperiment with 38 samples, 1082 features
# filtering for HC and disease
# AmpliconExperiment with 38 samples, 1082 features
# **********
# processing ../studies/10 (26)
# ['../studies/10/all.biom']
# 2021-04-05 19:58:50 INFO loaded 174 samples, 3295 features
# 2021-04-05 19:58:50 WARNING These have metadata but do not have data - dropped (2): {'SRR1689253', 'SRR1687461'}
# 2021-04-05 19:58:50 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:58:50 INFO After filtering, 174 remain.
# -------------
# AmpliconExperiment with 174 samples, 3295 features
# filtering for HC and disease
# AmpliconExperiment with 174 samples, 3295 features
# **********
# processing ../studies/19 (27)
# ['../studies/19/all.biom']
# 2021-04-05 19:59:08 INFO loaded 68 samples, 1401 features
# 2021-04-05 19:59:08 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:59:08 INFO After filtering, 68 remain.
# -------------
# AmpliconExperiment with 68 samples, 1401 features
# filtering for HC and disease
# AmpliconExperiment with 68 samples, 1401 features
# **********
# processing ../studies/26 (28)
# ['../studies/26/all.biom']
# 2021-04-05 19:59:25 INFO loaded 1388 samples, 11834 features
# 2021-04-05 19:59:25 WARNING These have metadata but do not have data - dropped (41): {'DB3.234', 'DB3.229', 'DB3.223', 'DB3.218', 'DB3.196', 'DB3.228', 'DB2.239', 'DB3.230', 'DB3.269', 'DB3.110', 'DB3.072', 'DB3.036', 'DB3.251', 'DB3.047', 'DB3.071', 'DB3.239', 'DB3.250', 'DB3.102', 'DB3.108', 'DB2.241', 'DB2.135', 'DB3.101', 'DB3.217', 'DB3.109', 'DB3.212', 'DB2.245', 'DB3.078', 'DB3.096', 'DB3.106', 'DB2.242', 'DB2.240', 'DB3.107', 'DB3.103', 'DB3.104', 'DB2.076', 'DB3.231', 'DB3.266', 'DB2.069', 'DB3.265', 'DB3.219', 'DB3.264'}
WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 19:59:58 INFO After filtering, 33 remain.
# -------------
# AmpliconExperiment with 33 samples, 780 features
# filtering for HC and disease
# AmpliconExperiment with 33 samples, 780 features
# **********
# processing ../studies/21 (30)
# ['../studies/21/all.biom']
# 2021-04-05 20:00:30 INFO loaded 178 samples, 2597 features
# 2021-04-05 20:00:30 WARNING These have metadata but do not have data - dropped (1): {'SRR6147218'}
# 2021-04-05 20:00:30 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:00:30 INFO After filtering, 178 remain.
# -------------
# AmpliconExperiment with 178 samples, 2597 features
# filtering for HC and disease
# AmpliconExperiment with 178 samples, 2597 features
# **********
# processing ../studies/44 (31)
# ['../studies/44/all.biom']
# 2021-04-05 20:01:04 INFO loaded 875 samples, 11915 features
# 2021-04-05 20:01:04 WARNING These have metadata but do not have data - dropped (64): {'ERR1545911', 'ERR1160673', 'ERR1545891', 'ERR1090161', 'ERR1545962', 'ERR1545986', 'ERR1545978', 'ERR1091354', 'ERR1089679', 'ERR1545802', 'ERR1074779', 'ERR1091155', 'ERR1545907', 'ERR1841813', 'ERR1075185', 'ERR1545774', 'ERR1074050', 'ERR1074092', 'ERR1545804', 'ERR1074007', 'ERR1160680', 'ERR1546016', 'ERR1072778', 'ERR1841525', 'ERR1597274', 'ERR1073198', 'ERR1089814', 'ERR1545780', 'ERR1074974', 'ERR1075896', 'ERR1073883', 'ERR1073330', 'ERR1075069', 'ERR1842199', 'ERR1545963', 'ERR1075272', 'ERR1546010', 'ERR2239717', 'ERR1074978', 'ERR1545939', 'ERR1545936', 'ERR1074005', 'ERR1072979', 'ERR1091147', 'ERR1545877', 'ERR2242158', 'ERR1080384', 'ERR1545747', 'ERR1545781', 'ERR1160475', 'ERR1074955', 'ERR1389624', 'ERR1545838', 'ERR1072794', 'ERR1545833', 'ERR1545990', 'ERR1545702', 'ERR1545803', 'ERR1546057', 'ERR1597126', 'ERR1389819', 'ERR1075071', 'ERR1072781', 'ERR1075286'}
# 2021-04-05 20:01:04 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:01:04 INFO After filtering, 835 remain.
# -------------
# AmpliconExperiment with 835 samples, 11915 features
# filtering for HC and disease
# AmpliconExperiment with 835 samples, 11915 features
# **********
# processing ../studies/43 (32)
# ['../studies/43/all.biom']
# 2021-04-05 20:01:52 INFO loaded 91 samples, 3426 features
# 2021-04-05 20:01:52 WARNING These have metadata but do not have data - dropped (9): {'ERR1545914', 'ERR1545813', 'ERR1075067', 'ERR1545849', 'ERR1841752', 'ERR1545876', 'ERR2239660', 'ERR1841803', 'ERR1073734'}
# 2021-04-05 20:01:52 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:01:52 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 3426 features
# filtering for HC and disease
# AmpliconExperiment with 89 samples, 3426 features
# **********
# processing ../studies/36 (33)
# ['../studies/36/all.biom']
# 2021-04-05 20:02:39 INFO loaded 16 samples, 1191 features
# 2021-04-05 20:02:39 WARNING These have metadata but do not have data - dropped (1): {'ERR1089974'}
# 2021-04-05 20:02:39 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:02:39 INFO After filtering, 15 remain.
# -------------
# AmpliconExperiment with 15 samples, 1191 features
# filtering for HC and disease
# AmpliconExperiment with 15 samples, 1191 features
# **********
# processing ../studies/31 (34)
# ['../studies/31/all.biom']
# 2021-04-05 20:03:24 INFO loaded 70 samples, 1929 features
# 2021-04-05 20:03:24 WARNING These have metadata but do not have data - dropped (18): {'ERR1331868', 'ERR1331858', 'ERR1331856', 'ERR1331867', 'ERR1331866', 'ERR1331871', 'ERR1331872', 'ERR1331865', 'ERR1331860', 'ERR1331869', 'ERR1331870', 'ERR1331864', 'ERR1331863', 'ERR1331862', 'ERR1331859', 'ERR1331861', 'ERR1331814', 'ERR1331857'}
# 2021-04-05 20:03:24 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:03:24 INFO After filtering, 70 remain.
# -------------
# AmpliconExperiment with 70 samples, 1929 features
# filtering for HC and disease
# AmpliconExperiment with 70 samples, 1929 features
# **********
# processing ../studies/62 (35)
# ['../studies/62/all.biom']
# 2021-04-05 20:04:07 INFO loaded 196 samples, 5813 features
# 2021-04-05 20:04:07 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:04:07 INFO After filtering, 196 remain.
# -------------
# AmpliconExperiment with 196 samples, 5813 features
# filtering for HC and disease
# AmpliconExperiment with 196 samples, 5813 features
# **********
# processing ../studies/54 (36)
# ['../studies/54/all.biom']
# 2021-04-05 20:04:54 INFO loaded 63 samples, 3657 features
# 2021-04-05 20:04:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:04:54 INFO After filtering, 63 remain.
# -------------
# AmpliconExperiment with 63 samples, 3657 features
# filtering for HC and disease
# AmpliconExperiment with 63 samples, 3657 features
# **********
# processing ../studies/53 (37)
# ['../studies/53/all.biom']
# 2021-04-05 20:05:42 INFO loaded 115 samples, 4878 features
# 2021-04-05 20:05:43 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:05:43 INFO After filtering, 115 remain.
# -------------
# AmpliconExperiment with 115 samples, 4878 features
# filtering for HC and disease
# AmpliconExperiment with 115 samples, 4878 features
# **********
# processing ../studies/37 (38)
# ['../studies/37/all.biom']
# 2021-04-05 20:06:32 INFO loaded 757 samples, 12055 features
# 2021-04-05 20:06:32 WARNING These have metadata but do not have data - dropped (63): {'ERR1072865', 'ERR1545954', 'ERR1545899', 'ERR1841696', 'ERR1545922', 'ERR1459193', 'ERR1458945', 'ERR2580081', 'ERR1545999', 'ERR1316091', 'ERR1091311', 'ERR1072872', 'ERR1545923', 'ERR1091687', 'ERR2239311', 'ERR1545837', 'ERR2239796', 'ERR1075799', 'ERR1545979', 'ERR1091094', 'ERR1545863', 'ERR1077624', 'ERR1080064', 'ERR2239648', 'ERR1075259', 'ERR1091073', 'ERR1091610', 'ERR1545856', 'ERR1315992', 'ERR1072691', 'ERR1075115', 'ERR1080269', 'ERR1545860', 'ERR1545721', 'ERR1545995', 'ERR1545931', 'ERR1073095', 'ERR1073219', 'ERR1458825', 'ERR2239672', 'ERR2239737', 'ERR1842276', 'ERR1841719', 'ERR1841811', 'ERR1091136', 'ERR1546066', 'ERR1545835', 'ERR1389679', 'ERR1546000', 'ERR1075296', 'ERR1545811', 'ERR1090142', 'ERR1389829', 'ERR2238737', 'ERR1091704', 'ERR2239190', 'ERR1076845', 'ERR1091456', 'ERR1074977', 'ERR1545934', 'ERR1841820', 'ERR1545779', 'ERR1072933'}
# 2021-04-05 20:06:32 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:06:32 INFO After filtering, 727 remain.
# -------------
# AmpliconExperiment with 727 samples, 12055 features
# filtering for HC and disease
# AmpliconExperiment with 727 samples, 12055 features
# **********
# processing ../studies/39 (39)
# ['../studies/39/all.biom']
# 2021-04-05 20:07:29 INFO loaded 625 samples, 10422 features
# 2021-04-05 20:07:29 WARNING These have metadata but do not have data - dropped (35): {'ERR2238658', 'ERR1074953', 'ERR1841821', 'ERR1074855', 'ERR2239697', 'ERR1545875', 'ERR1854699', 'ERR2239793', 'ERR1080069', 'ERR2239393', 'ERR1073258', 'ERR2239770', 'ERR1841495', 'ERR1075897', 'ERR2318018', 'ERR1072703', 'ERR1545942', 'ERR1073829', 'ERR1545903', 'ERR1545815', 'ERR1842590', 'ERR2238750', 'ERR1545969', 'ERR1077488', 'ERR1089998', 'ERR1389924', 'ERR1074160', 'ERR1842514', 'ERR2239308', 'ERR1072835', 'ERR1841812', 'ERR1545985', 'ERR1545842', 'ERR1389959', 'ERR1076837'}
# 2021-04-05 20:07:30 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:07:30 INFO After filtering, 587 remain.
# -------------
# AmpliconExperiment with 587 samples, 10422 features
# filtering for HC and disease
# AmpliconExperiment with 587 samples, 10422 features
# **********
# processing ../studies/52 (40)
# ['../studies/52/all.biom']
# 2021-04-05 20:08:31 INFO loaded 30 samples, 2580 features
# 2021-04-05 20:08:31 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:08:31 INFO After filtering, 30 remain.
# -------------
# AmpliconExperiment with 30 samples, 2580 features
# filtering for HC and disease
# AmpliconExperiment with 30 samples, 2580 features
# **********
# processing ../studies/55 (41)
# ['../studies/55/all.biom']
# 2021-04-05 20:09:31 INFO loaded 74 samples, 3939 features
# 2021-04-05 20:09:31 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:09:31 INFO After filtering, 74 remain.
# -------------
# AmpliconExperiment with 74 samples, 3939 features
# filtering for HC and disease
# AmpliconExperiment with 74 samples, 3939 features
# **********
# processing ../studies/46 (42)
# ['../studies/46/all.biom']
# 2021-04-05 20:10:31 INFO loaded 584 samples, 10980 features
# 2021-04-05 20:10:31 WARNING These have metadata but do not have data - dropped (41): {'ERR1545904', 'ERR2238718', 'ERR1075338', 'ERR2239702', 'ERR1073073', 'ERR1545701', 'ERR1077699', 'ERR1546003', 'ERR1089788', 'ERR1545968', 'ERR1459007', 'ERR1546040', 'ERR1854779', 'ERR1075243', 'ERR2304178', 'ERR1841755', 'ERR1074261', 'ERR1074885', 'ERR1841818', 'ERR1074071', 'ERR1080238', 'ERR1545694', 'ERR1841546', 'ERR1089939', 'ERR1075226', 'ERR1545678', 'ERR1545890', 'ERR1545910', 'ERR1073933', 'ERR1545902', 'ERR1545916', 'ERR2239804', 'ERR1073802', 'ERR1546027', 'ERR1073744', 'ERR1545859', 'ERR1389664', 'ERR1545965', 'ERR2242536', 'ERR2239582', 'ERR1545961'}
# 2021-04-05 20:10:31 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:10:31 INFO After filtering, 554 remain.
# -------------
# AmpliconExperiment with 554 samples, 10980 features
# filtering for HC and disease
# AmpliconExperiment with 554 samples, 10980 features
# **********
# processing ../studies/41 (43)
# ['../studies/41/all.biom']
# 2021-04-05 20:11:42 INFO loaded 84 samples, 3557 features
# 2021-04-05 20:11:42 WARNING These have metadata but do not have data - dropped (5): {'ERR1075045', 'ERR2238709', 'ERR1545772', 'ERR1160360', 'ERR2238703'}
# 2021-04-05 20:11:42 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:11:42 INFO After filtering, 80 remain.
# -------------
# AmpliconExperiment with 80 samples, 3557 features
# filtering for HC and disease
# AmpliconExperiment with 80 samples, 3557 features
# **********
# processing ../studies/48 (44)
# ['../studies/48/all.biom']
# 2021-04-05 20:12:46 INFO loaded 293 samples, 6184 features
# 2021-04-05 20:12:46 WARNING These have metadata but do not have data - dropped (21): {'ERR2239290', 'ERR1075875', 'ERR1090826', 'ERR1545775', 'ERR1545869', 'ERR2308577', 'ERR1545878', 'ERR1160560', 'ERR2238646', 'ERR1841718', 'ERR1075817', 'ERR1089851', 'ERR1091689', 'ERR1546021', 'ERR1546022', 'ERR1089874', 'ERR1073280', 'ERR1089880', 'ERR2033565', 'ERR1091390', 'ERR1841798'}
# 2021-04-05 20:12:47 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:12:47 INFO After filtering, 280 remain.
# -------------
# AmpliconExperiment with 280 samples, 6184 features
# filtering for HC and disease
# AmpliconExperiment with 280 samples, 6184 features
# **********
# processing ../studies/24 (45)
# ['../studies/24/all.biom']
# 2021-04-05 20:13:56 INFO loaded 25 samples, 999 features
# 2021-04-05 20:13:56 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:13:56 INFO After filtering, 25 remain.
# -------------
# AmpliconExperiment with 25 samples, 999 features
# filtering for HC and disease
# AmpliconExperiment with 25 samples, 999 features
# **********
# processing ../studies/23 (46)
# ['../studies/23/all.biom']
# 2021-04-05 20:15:02 INFO loaded 114 samples, 1867 features
# 2021-04-05 20:15:02 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:15:02 INFO After filtering, 114 remain.
# -------------
# AmpliconExperiment with 114 samples, 1867 features
# filtering for HC and disease
# AmpliconExperiment with 114 samples, 1867 features
# **********
# processing ../studies/4 (47)
# ['../studies/4/all.biom']
# 2021-04-05 20:16:06 INFO loaded 83 samples, 1652 features
# 2021-04-05 20:16:06 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:16:06 INFO After filtering, 82 remain.
# -------------
# AmpliconExperiment with 82 samples, 1652 features
# filtering for HC and disease
# AmpliconExperiment with 82 samples, 1652 features
# **********
# processing ../studies/15 (48)
# ['../studies/15/all.biom']
# 2021-04-05 20:17:10 INFO loaded 174 samples, 2103 features
# 2021-04-05 20:17:10 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:17:10 INFO After filtering, 162 remain.
# -------------
# AmpliconExperiment with 162 samples, 2103 features
# filtering for HC and disease
# AmpliconExperiment with 162 samples, 2103 features
# **********
# processing ../studies/3 (49)
# ['../studies/3/all.biom']
# 2021-04-05 20:18:15 INFO loaded 337 samples, 3021 features
# 2021-04-05 20:18:15 WARNING These have metadata but do not have data - dropped (11): {'ERR1513792', 'ERR1513697', 'ERR1513809', 'ERR1513852', 'ERR1513897', 'ERR1513791', 'ERR1513823', 'ERR1513668', 'ERR1513848', 'ERR1513720', 'ERR1513893'}
# 2021-04-05 20:18:15 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20
WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:19:22 INFO After filtering, 2373 remain.
# -------------
# AmpliconExperiment with 2373 samples, 13732 features
# filtering for HC and disease
# AmpliconExperiment with 224 samples, 13732 features
# **********
# processing ../studies/49 (52)
# ['../studies/49/all.biom']
# 2021-04-05 20:20:38 INFO loaded 273 samples, 8112 features
# 2021-04-05 20:20:38 WARNING These have metadata but do not have data - dropped (28): {'ERR1545766', 'ERR1545737', 'ERR1545712', 'ERR1074598', 'ERR1545980', 'ERR1074963', 'ERR1545898', 'ERR1091143', 'ERR1841753', 'ERR1546004', 'ERR1841517', 'ERR2032154', 'ERR1080264', 'ERR1545971', 'ERR1090164', 'ERR1545713', 'ERR1091007', 'ERR1090991', 'ERR2238662', 'ERR1546037', 'ERR1545736', 'ERR1091581', 'ERR1091017', 'ERR1090999', 'ERR1090029', 'ERR1545777', 'ERR1841808', 'ERR1075006'}
# 2021-04-05 20:20:38 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:20:38 INFO After filtering, 263 remain.
# -------------
# AmpliconExperiment with 263 samples, 8112 features
# filtering for HC and disease
# AmpliconExperiment with 263 samples, 8112 features
# **********
# processing ../studies/40 (53)
# ['../studies/40/all.biom']
# 2021-04-05 20:21:52 INFO loaded 86 samples, 3917 features
# 2021-04-05 20:21:52 WARNING These have metadata but do not have data - dropped (7): {'ERR1073218', 'ERR2580024', 'ERR1091444', 'ERR1091053', 'ERR1841756', 'ERR1090007', 'ERR1075021'}
# 2021-04-05 20:21:52 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:21:52 INFO After filtering, 85 remain.
# -------------
# AmpliconExperiment with 85 samples, 3917 features
# filtering for HC and disease
# AmpliconExperiment with 85 samples, 3917 features
# **********
# processing ../studies/47 (54)
# ['../studies/47/all.biom']
# 2021-04-05 20:23:05 INFO loaded 257 samples, 7437 features
# 2021-04-05 20:23:05 WARNING These have metadata but do not have data - dropped (17): {'ERR1074882', 'ERR1545836', 'ERR1545948', 'ERR1545812', 'ERR1841629', 'ERR1091158', 'ERR1073703', 'ERR1458779', 'ERR1160308', 'ERR1841809', 'ERR1545953', 'ERR1073252', 'ERR1091085', 'ERR1091044', 'ERR1841777', 'ERR1841802', 'ERR1546002'}
# 2021-04-05 20:23:05 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:23:05 INFO After filtering, 247 remain.
# -------------
# AmpliconExperiment with 247 samples, 7437 features
# filtering for HC and disease
# AmpliconExperiment with 247 samples, 7437 features
# **********
# processing ../studies/2 (55)
# ['../studies/2/all.biom']
# 2021-04-05 20:24:24 INFO loaded 179 samples, 2528 features
# 2021-04-05 20:24:24 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:24:24 INFO After filtering, 179 remain.
# -------------
# AmpliconExperiment with 179 samples, 2528 features
# filtering for HC and disease
# AmpliconExperiment with 179 samples, 2528 features
# **********
# processing ../studies/13 (56)
# ['../studies/13/all.biom']
# 2021-04-05 20:25:40 INFO loaded 31 samples, 925 features
# 2021-04-05 20:25:40 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20
# 2021-04-05 20:28:22 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:28:22 INFO After filtering, 123 remain.
# -------------
# AmpliconExperiment with 123 samples, 1271 features
# filtering for HC and disease
# AmpliconExperiment with 123 samples, 1271 features
# **********
# processing ../studies/22 (59)
# ['../studies/22/all.biom']
# 2021-04-05 20:29:54 INFO loaded 144 samples, 2687 features
# 2021-04-05 20:29:54 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:29:54 INFO After filtering, 144 remain.
# -------------
# AmpliconExperiment with 144 samples, 2687 features
# filtering for HC and disease
# AmpliconExperiment with 144 samples, 2687 features
# **********
# processing ../studies/25 (61)
# ['../studies/25/all.biom']
# 2021-04-05 20:31:29 INFO loaded 92 samples, 1781 features
# 2021-04-05 20:31:29 WARNING These have metadata but do not have data - dropped (1): {'ERR1776941'}
# 2021-04-05 20:31:29 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 20:31:29 INFO After filtering, 89 remain.
# -------------
# AmpliconExperiment with 89 samples, 1781 features
# filtering for HC and disease
# AmpliconExperiment with 89 samples, 1781 features
# finished. Total processed 62. Total ok 59. Not enough samples 0

# %%
expall.description='merged no subsampling'
expall
# Out:
# AmpliconExperiment ("merged no subsampling") with 11459 samples, 44537 features

# %%
expall.save('../allsamples/allsamples-no-subsampling')
# Out:
# 2021-04-05 20:33:17 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %%
expall.sample_metadata.exp.value_counts()
# Out:
# ../studies/45    1043
# ../studies/44     835
# ../studies/37     727
# ../studies/6      612
# ../studies/29     594
# ../studies/39     587
# ../studies/46     554
# ../studies/9      451
# ../studies/7      441
# ../studies/3      334
# ../studies/5      333
# ../studies/48     280
# ../studies/49     263
# ../studies/47     247
# ../studies/27     233
# ../studies/12     224
# ../studies/62     196
# ../studies/2      179
# ../studies/21     178
# ../studies/10     174
# ../studies/51     164
# ../studies/15     162
# ../studies/20     151
# ../studies/22     144
# ../studies/28     135
# ../studies/14     123
# ../studies/16     119
# ../studies/53     115
# ../studies/23     114
# ../studies/11     109
# ../studies/42      96
# ../studies/25      89
# ../studies/43      89
# ../studies/57      85
# ../studies/40      85
# ../studies/18      84
# ../studies/4       82
# ../studies/41      80
# ../studies/55      74
# ../studies/60      73
# ../studies/31      70
# ../studies/19      68
# ../studies/54      63
# ../studies/33      58
# ../studies/50      58
# ../studies/17      50
# ../studies/58      45
# ../studies/56      43
# ../studies/32      43
# ../studies/61      41
# ../studies/1       38
# ../studies/8       33
# ../studies/59      33
# ../studies/34      32
# ../studies/13      31
# ../studies/52      30
# ../studies/24      25
# ../studies/26      25
# ../studies/36      15
# Name: exp, dtype: int64

# %% [markdown]
# ## Also save after filtering for blooiming bacteria

# %%
expall=expall.filter_by_fasta('../allsamples/blooming-bacteria.fa',negate=True)

# %%
expall.save('../allsamples/allsamples-no-subsampling-no-bloom')
# Out:
# 2021-04-05 20:34:01 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %% [markdown]
# # Load the data
# (up to 23 control and 23 cases in each study)

# %%
exp=ca.read_amplicon('../allsamples/allsamples-no-bloom.biom',
                     '../allsamples/allsamples-no-bloom_sample.txt',
                     min_reads=1000, normalize=10000)
# Out:
# 2021-04-05 22:16:40 INFO loaded 2533 samples, 44526 features
# /Users/amnon/miniconda3/envs/calour/lib/python3.7/site-packages/ipykernel_launcher.py:3: DtypeWarning: Columns (7,8,9,11,12,13,14,21,23,28,36,40,43,48,50,52,54,55,56,57,58,59,61,63,64,65,66,69,70,71,72,73,75,77,79,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,103,106,107,108,110,113,114,115,118,120,121,122,123,124,125,127,129,131,132,133,134,135,137,138,140,145,146,147,148,152,153,154,155,156,157,158,159,160,162,163,164,165,166,167,168,169,170,171,185,186,189,190,191,192,193,194,195,196,197,199,200,201,202,203,205,206,207,208,209,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,239,240,242,243,260,261,263,264,265,266,269,270,272,332,333,336,337,341,342,343) have mixed types.Specify dtype option on import or set low_memory=False.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 2021-04-05 22:16:45 WARNING Do you forget to normalize your data? It is required before running this function
# 2021-04-05 22:16:45 INFO After filtering, 2514 remain.

# %%
exp
# Out:
# AmpliconExperiment with 2514 samples, 44526 features

# %% [markdown]
# ### Keep only features present in at least 10 samples
# (so we filter min_prevalence 9.5/num_of_samples

# %%
tt=exp.filter_prevalence(9.5/len(exp.sample_metadata))
tt
# Out:
# 2021-04-05 22:16:50 INFO After filtering, 2692 remain.
# AmpliconExperiment with 2514 samples, 2692 features

# %% [markdown]
# ### merge by sample type for taxonomy plot

# %%
tt=exp.join_metadata_fields('exp','type','exptype',axis=0,inplace=False)

# %%
tt=tt.aggregate_by_metadata('exptype', agg='mean')

# %%
tt=tt.sort_samples('exp')

# %%
cu.splot(tt,'type')
# Out:
# creating logger

# %%
tt.save('../allsamples/cohort-disease-mean')
# Out:
# 2021-04-05 22:17:05 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %% [markdown]
# ### Save separately the healthy and sick groups

# %%
ttt=tt.filter_samples('type','HC')
ttt
# Out:
# AmpliconExperiment with 59 samples, 44526 features

# %%
ttt.save('../allsamples/cohort-disease-mean-HC')
# Out:
# 2021-04-05 22:17:08 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %%
ttt=tt.filter_samples('type','disease')
ttt
# Out:
# AmpliconExperiment with 59 samples, 44526 features

# %%
ttt.save('../allsamples/cohort-disease-mean-disease')
# Out:
# 2021-04-05 22:17:10 INFO Metadata field taxonomy not found. Saving biom table without metadata

# %% [markdown]
# ### Save single combined healthy/sick (for all cohorts together)

# %%
ttt=tt.aggregate_by_metadata('type', agg='mean')
ttt
# Out:
# AmpliconExperiment with 2 samples, 44526 features

# %%
ttt.save('../allsamples/mean-type-combined')
# Out:
# 2021-04-05 22:17:12 INFO Metadata field taxonomy not found. Saving biom table without metadata
